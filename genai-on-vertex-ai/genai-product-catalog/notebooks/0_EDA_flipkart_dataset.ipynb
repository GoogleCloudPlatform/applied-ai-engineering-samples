# %% [markdown]
# # Overview
#
# This notebook explores the example dataset we will use and creates a BigQuery table with said data.
#
# Input:
#
# [Kaggle Flipkart Product Catalog Dataset](https://www.kaggle.com/datasets/PromptCloudHQ/flipkart-products)
#
# Output:
#
# BigQuery table in a schema compatible for use in downstream notebooks.

# %% [markdown]
# ### Authenticate
#
# If you are using Colab, you will need to authenticate yourself first. The next cell will check if you are currently using Colab, and will start the authentication process.

# %%
import sys
if 'google.colab' in sys.modules:
    from google.colab import auth as google_auth
    google_auth.authenticate_user()

# %% [markdown]
# ## Installation & Configurations

# %%
# !pip install spacy
# !pip install spacy-cleaner
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.3)
# Collecting spacy-cleaner
#   Downloading spacy_cleaner-3.1.3-py3-none-any.whl (15 kB)
# Collecting spacy<3.5.0,>=3.4.1 (from spacy-cleaner)
#   Downloading spacy-3.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 45.4 MB/s eta 0:00:00
# Collecting spacy-lookups-data<1.1.0,>=1.0.3 (from spacy-cleaner)
#   Downloading spacy_lookups_data-1.0.5-py2.py3-none-any.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 9.0 MB/s eta 0:00:00
# Collecting tqdm<4.65.0,>=4.64.0 (from spacy-cleaner)
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (8.1.12)
# Collecting wasabi<1.1.0,>=0.9.1 (from spacy<3.5.0,>=3.4.1->spacy-cleaner)
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (2.0.10)
# Collecting typer<0.8.0,>=0.3.0 (from spacy<3.5.0,>=3.4.1->spacy-cleaner)
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (6.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.1->spacy-cleaner) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.1->spacy-cleaner) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->spacy-cleaner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->spacy-cleaner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->spacy-cleaner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->spacy-cleaner) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->spacy-cleaner) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->spacy-cleaner) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.1->spacy-cleaner) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.5.0,>=3.4.1->spacy-cleaner) (2.1.3)
# Installing collected packages: wasabi, typer, tqdm, spacy-lookups-data, spacy, spacy-cleaner
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.2
#     Uninstalling wasabi-1.1.2:
#       Successfully uninstalled wasabi-1.1.2
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.6.1
#     Uninstalling spacy-3.6.1:
#       Successfully uninstalled spacy-3.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# en-core-web-sm 3.6.0 requires spacy<3.7.0,>=3.6.0, but you have spacy 3.4.4 which is incompatible.
# Successfully installed spacy-3.4.4 spacy-cleaner-3.1.3 spacy-lookups-data-1.0.5 tqdm-4.64.1 typer-0.7.0 wasabi-0.10.1

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
# !python -m spacy validate
# !python -m spacy download en_core_web_sm
# Out:
# 2023-11-21 19:13:31.135084: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 19:13:31.135180: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 19:13:31.135222: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 19:13:31.145571: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-21 19:13:33.129054: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Loaded compatibility table
#
# ================= Installed pipeline packages (spaCy v3.4.4) =================
# ℹ spaCy installation: /usr/local/lib/python3.10/dist-packages/spacy
#
# NAME             SPACY            VERSION
# en_core_web_sm   >=3.6.0,<3.7.0   3.6.0   --> 3.4.1
#
#
# ============================== Install updates ==============================
# Use the following commands to update the packages:
# python -m spacy download en_core_web_sm
#
# 2023-11-21 19:13:44.436425: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 19:13:44.436494: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 19:13:44.436524: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 19:13:44.442510: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-21 19:13:45.457524: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 75.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.3)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.6.0
#     Uninstalling en-core-web-sm-3.6.0:
#       Successfully uninstalled en-core-web-sm-3.6.0
# Successfully installed en-core-web-sm-3.4.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install google-cloud-storage

# %%
# !python -m pip install openpyxl

# %% [markdown]
# # Dataset
#
# [This](https://www.kaggle.com/datasets/PromptCloudHQ/flipkart-products) is a pre-crawled dataset, taken as subset of a bigger dataset (more than 5.8 million products) that was created by extracting data from [Flipkart](https://www.flipkart.com/), a leading Indian eCommerce store.

# %%
import pandas as pd
full_ds = pd.read_csv('gs://product_catalog_enrichment/flipkart_20k/flipkart_com-ecommerce_sample.csv')

# %%
full_ds.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
#
#    retail_price  discounted_price  \
# 0         999.0             379.0
# 1       32157.0           22646.0
# 2         999.0             499.0
# 3         699.0             267.0
# 4         220.0             210.0
#
#                                                image  is_FK_Advantage_product  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...                    False
# 1  ["http://img6a.flixcart.com/image/sofa-bed/j/f...                    False
# 2  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...                    False
# 3  ["http://img5a.flixcart.com/image/short/6/2/h/...                    False
# 4  ["http://img5a.flixcart.com/image/pet-shampoo/...                    False
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2  Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4  Specifications of Sicons All Purpose Arnica Do...  No rating available
#
#         overall_rating         brand  \
# 0  No rating available        Alisha
# 1  No rating available  FabHomeDecor
# 2  No rating available            AW
# 3  No rating available        Alisha
# 4  No rating available        Sicons
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Number of ...
# 1  {"product_specification"=>[{"key"=>"Installati...
# 2  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  {"product_specification"=>[{"key"=>"Number of ...
# 4  {"product_specification"=>[{"key"=>"Pet Type",...

# %%
full_ds['image'][0]
# Out:
# '["http://img5a.flixcart.com/image/short/u/4/a/altht-3p-21-alisha-38-original-imaeh2d5vm5zbtgg.jpeg", "http://img5a.flixcart.com/image/short/p/j/z/altght4p-26-alisha-38-original-imaeh2d5kbufss6n.jpeg", "http://img5a.flixcart.com/image/short/p/j/z/altght4p-26-alisha-38-original-imaeh2d5npdybzyt.jpeg", "http://img5a.flixcart.com/image/short/z/j/7/altght-7-alisha-38-original-imaeh2d5jsz2ghd6.jpeg"]'

# %%
full_ds['description'][0]
# Out:
# "Key Features of Alisha Solid Women's Cycling Shorts Cotton Lycra Navy, Red, Navy,Specifications of Alisha Solid Women's Cycling Shorts Shorts Details Number of Contents in Sales Package Pack of 3 Fabric Cotton Lycra Type Cycling Shorts General Details Pattern Solid Ideal For Women's Fabric Care Gentle Machine Wash in Lukewarm Water, Do Not Bleach Additional Details Style Code ALTHT_3P_21 In the Box 3 shorts"

# %%
# check the values of each row for each column
n = full_ds.nunique(axis=0)
print("No.of.unique values in each column :\n", n)
# Out:
# No.of.unique values in each column :
#  uniq_id                    20000
# crawl_timestamp              371
# product_url                20000
# product_name               12676
# product_category_tree       6466
# pid                        19998
# retail_price                2247
# discounted_price            2448
# image                      18589
# is_FK_Advantage_product        2
# description                17539
# product_rating                36
# overall_rating                36
# brand                       3499
# product_specifications     18825
# dtype: int64

# %%
full_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
#  14  product_specifications   19986 non-null  object
# dtypes: bool(1), float64(2), object(12)
# memory usage: 2.2+ MB

# %%
full_ds.describe()
# Out:
#         retail_price  discounted_price
# count   19922.000000      19922.000000
# mean     2979.206104       1973.401767
# std      9009.639341       7333.586040
# min        35.000000         35.000000
# 25%       666.000000        350.000000
# 50%      1040.000000        550.000000
# 75%      1999.000000        999.000000
# max    571230.000000     571230.000000

# %%
df = full_ds[['uniq_id','product_name','description','brand','product_category_tree','image','product_specifications']]

# %%
#df[~df['product_category_tree']]
df['product_category_tree'].isnull().sum()
# Out:
# 0

# %%
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
# Out:
# <ipython-input-11-9efa69e7ea20>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df.head()
# Out:
#                             uniq_id                           product_name  \
# 0  c2d766ca982eca8304150849735ffef9    Alisha Solid Women's Cycling Shorts
# 1  7f7036a6d550aaa89d34c77bd39a5e48    FabHomeDecor Fabric Double Sofa Bed
# 2  f449ec65dcbc041b6ae5e6a32717d01b                             AW Bellies
# 3  0973b37acd0c664e3de26e97e5571454    Alisha Solid Women's Cycling Shorts
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  Sicons All Purpose Arnica Dog Shampoo
#
#                                          description         brand  \
# 0  Key Features of Alisha Solid Women's Cycling S...        Alisha
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  FabHomeDecor
# 2  Key Features of AW Bellies Sandals Wedges Heel...            AW
# 3  Key Features of Alisha Solid Women's Cycling S...        Alisha
# 4  Specifications of Sicons All Purpose Arnica Do...        Sicons
#
#                                product_category_tree  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...
# 1  ["Furniture >> Living Room Furniture >> Sofa B...
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...
#
#                                                image  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1  ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3  ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4  ["http://img5a.flixcart.com/image/pet-shampoo/...
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Number of ...
# 1  {"product_specification"=>[{"key"=>"Installati...
# 2  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  {"product_specification"=>[{"key"=>"Number of ...
# 4  {"product_specification"=>[{"key"=>"Pet Type",...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uniq_id                 20000 non-null  object
#  1   product_name            20000 non-null  object
#  2   description             19998 non-null  object
#  3   brand                   14136 non-null  object
#  4   product_category_tree   20000 non-null  object
#  5   image                   19997 non-null  object
#  6   product_specifications  19986 non-null  object
# dtypes: object(7)
# memory usage: 1.1+ MB

# %% [markdown]
# # Category Analysis

# %%
#Helper function to reformat the given text
def reformat(text: str) -> str:
  text = text.replace('[', '')
  text = text.replace(']', '')
  text = text.replace('"', '')
  return text

#df.loc[:, 'product_category_tree'] = df['product_category_tree'].apply(lambda x: reformat(x))
df['product_category_tree'] = df['product_category_tree'].apply(lambda x: reformat(x))
# Out:
# <ipython-input-12-d65735fe80ed>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['product_category_tree'] = df['product_category_tree'].apply(lambda x: reformat(x))

# %%
# Finding the depth of the category trees
# Finding total number of categories in each level
cat_len = {}
for cat_tree in df.product_category_tree:
  number_of_categories = len(cat_tree.split(">>"))
  #print(number_of_categories)
  if number_of_categories not in cat_len:
    cat_len[number_of_categories] = 1
  else:
    cat_len[number_of_categories] += 1
print(cat_len)
# Out:
# {6: 3640, 4: 4765, 5: 4911, 1: 328, 3: 4419, 7: 778, 2: 1129, 8: 30}

# %% [markdown]
# **There are total 8 levels at max.**

# %%
temp_df = df['product_category_tree'].str.split('>>', expand=True)
temp_df.columns = ['c0_name', 'c1_name', 'c2_name', 'c3_name', 'c4_name', 'c5_name', 'c6_name', 'c7_name']
for col in temp_df.columns:
  temp_df[col] = temp_df[col].apply(lambda x: x.strip() if x else x)

# %% [markdown]
# **Considering only 4 levels from category tree**

# %%
#Considering only 4 levels from category tree
temp_df =temp_df[['c0_name', 'c1_name', 'c2_name', 'c3_name']]
temp_df
# Out:
#             c0_name                c1_name                     c2_name  \
# 0          Clothing       Women's Clothing  Lingerie, Sleep & Swimwear
# 1         Furniture  Living Room Furniture          Sofa Beds & Futons
# 2          Footwear       Women's Footwear                  Ballerinas
# 3          Clothing       Women's Clothing  Lingerie, Sleep & Swimwear
# 4      Pet Supplies               Grooming            Skin & Coat Care
# ...             ...                    ...                         ...
# 19995     Baby Care      Baby & Kids Gifts                    Stickers
# 19996     Baby Care      Baby & Kids Gifts                    Stickers
# 19997     Baby Care      Baby & Kids Gifts                    Stickers
# 19998     Baby Care      Baby & Kids Gifts                    Stickers
# 19999     Baby Care      Baby & Kids Gifts                    Stickers
#
#                                                  c3_name
# 0                                                 Shorts
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                                             AW Bellies
# 3                                                 Shorts
# 4                                                Shampoo
# ...                                                  ...
# 19995                                WallDesign Stickers
# 19996                                Wallmantra Stickers
# 19997                          Elite Collection Stickers
# 19998                          Elite Collection Stickers
# 19999                          Elite Collection Stickers
#
# [20000 rows x 4 columns]

# %%
# concatenating df1 and df2 along rows
df_with_cat = pd.concat([df, temp_df], axis=1)
df_with_cat = df_with_cat.drop('product_category_tree', axis=1)

# %%
df_with_cat.head()
# Out:
#                             uniq_id                           product_name  \
# 0  c2d766ca982eca8304150849735ffef9    Alisha Solid Women's Cycling Shorts
# 1  7f7036a6d550aaa89d34c77bd39a5e48    FabHomeDecor Fabric Double Sofa Bed
# 2  f449ec65dcbc041b6ae5e6a32717d01b                             AW Bellies
# 3  0973b37acd0c664e3de26e97e5571454    Alisha Solid Women's Cycling Shorts
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  Sicons All Purpose Arnica Dog Shampoo
#
#                                          description         brand  \
# 0  Key Features of Alisha Solid Women's Cycling S...        Alisha
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  FabHomeDecor
# 2  Key Features of AW Bellies Sandals Wedges Heel...            AW
# 3  Key Features of Alisha Solid Women's Cycling S...        Alisha
# 4  Specifications of Sicons All Purpose Arnica Do...        Sicons
#
#                                                image  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1  ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3  ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4  ["http://img5a.flixcart.com/image/pet-shampoo/...
#
#                               product_specifications       c0_name  \
# 0  {"product_specification"=>[{"key"=>"Number of ...      Clothing
# 1  {"product_specification"=>[{"key"=>"Installati...     Furniture
# 2  {"product_specification"=>[{"key"=>"Ideal For"...      Footwear
# 3  {"product_specification"=>[{"key"=>"Number of ...      Clothing
# 4  {"product_specification"=>[{"key"=>"Pet Type",...  Pet Supplies
#
#                  c1_name                     c2_name  \
# 0       Women's Clothing  Lingerie, Sleep & Swimwear
# 1  Living Room Furniture          Sofa Beds & Futons
# 2       Women's Footwear                  Ballerinas
# 3       Women's Clothing  Lingerie, Sleep & Swimwear
# 4               Grooming            Skin & Coat Care
#
#                                              c3_name
# 0                                             Shorts
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                                         AW Bellies
# 3                                             Shorts
# 4                                            Shampoo

# %%
#Saving the categories into an xlsx on local
columns = temp_df.columns
with pd.ExcelWriter('flipkart_cat_analysis_cat_depth4.xlsx') as writer:
  for col in columns:
    temp_df[col].value_counts().to_excel(writer, sheet_name=col)

# %% [markdown]
# # Product Description Prep

# %%
#Cleaning the description text
import spacy
import spacy_cleaner
from spacy_cleaner.processing import removers, replacers, mutators

MODEL = spacy.load("en_core_web_sm")

PROC_PIPELINE = spacy_cleaner.Pipeline(
    MODEL,
    replacers.replace_punctuation_token,
    mutators.mutate_lemma_token,
    removers.remove_stopword_token,

)
def parse_nlp_description(description) -> str:
    #print(description)
    if pd.isna(description):
      return " "
    doc = MODEL(description.lower())
    lemmas = []
    for token in doc:
        if token.lemma_ not in lemmas and not token.is_stop and token.is_alpha:
            lemmas.append(token.lemma_)

    return " ".join(lemmas)

#test
#DESCRIPTION = "Solemio Sleeveless Solid Men's Reversible Sweatshirt Price: Rs. 1,261 Fitz Blue Sweat Shirt is a must-have for any wardrobe. Ensemble with trendy embroidery on the chest and full zipped closure down front. It is marked with ribbed waistband, cuffs and two pouch pockets on the front. Classic color scheme allows you to wear this over a wide range of separates. Relaxed fit for free body movement. Brand: Fitz Color: Red Style Statement: Designed to be worn as casual as well as leisure wear. Team it with a denims and sneakers to look uber cool. Material: Polyester Cotton Wash Care: Do not bleach and tumble dry. Use gentle machine wash and gentle warm Iron. About the brand: FITZ is the company’s flagship sportswear and active wear brand with an Indian soul and international outlook. It is an evolved range of sports and activity gears dedicated to sports enthusiasts. The brand is poised to become an economic force when it comes to young people who are aware of style trends, sportswear designs reflected the spirited, celebrity-conscious sensibilities of the decade. Disclaimer: Product color may slightly vary due to photographic lighting sources or your monitor settings. Size varies from brand to brand. Kindly go through the size chart for more clarity. Fitz Blue Sweat Shirt is a must-have for any wardrobe. Ensemble with trendy embroidery on the chest and full zipped closure down front. It is marked with ribbed waistband, cuffs and two pouch pockets on the front. Classic color scheme allows you to wear this over a wide range of separates. Relaxed fit for free body movement. Brand: Fitz Color: Red Style Statement: Designed to be worn as casual as well as leisure wear. Team it with a denims and sneakers to look uber cool. Material: Polyester Cotton Wash Care: Do not bleach and tumble dry. Use gentle machine wash and gentle warm Iron. About the brand: FITZ is the company’s flagship sportswear and active wear brand with an Indian soul and international outlook. It is an evolved range of sports and activity gears dedicated to sports enthusiasts. The brand is poised to become an economic force when it comes to young people who are aware of style trends, sportswear designs reflected the spirited, celebrity-conscious sensibilities of the decade. Disclaimer: Product color may slightly vary due to photographic lighting sources or your monitor settings. Size varies from brand to brand. Kindly go through the size chart for more clarity."
#print(len(DESCRIPTION))

#print(parse_nlp_description(DESCRIPTION))
#print(len(parse_nlp_description(DESCRIPTION)))

# %%
df_with_cat['description'] = df_with_cat['description'].apply(lambda x: parse_nlp_description(x))

# %%
#df_with_cat.head()

# %% [markdown]
# # Extracting Product Attributes

# %%
#Extracting attributes from product specifications
import json
from typing import List, Dict

import jsonpickle
import pandas as pd
import re

import numpy as np
SPEC_MATCH_ONE = re.compile("(.*?)\\[(.*)\\](.*)")
SPEC_MATCH_TWO = re.compile("(.*?)=>\"(.*?)\"(.*?)=>\"(.*?)\"(.*)")

def parse_spec(specification: str):
    if pd.isna(specification):
      return None
    m = SPEC_MATCH_ONE.match(specification)
    out = {}
    position = 0
    if m is not None and m.group(2) is not None:
        phrase = ''
        for c in m.group(2):
            if c == '}':
                m2 = SPEC_MATCH_TWO.match(phrase)
                if m2 and m2.group(2) is not None and m2.group(4) is not None:
                    out[m2.group(2)]=m2.group(4)
                phrase = ''
            else:
                phrase += c
    json_string = jsonpickle.encode(out)
    print(json_string)
    return json_string

# %%
df_with_cat['attributes'] = df_with_cat['product_specifications'].apply(parse_spec)
# Out:
# Streaming output truncated to the last 5000 lines.
# {"Brand Color": "Grey", "color": "Grey", "Ideal For": "Women's", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non-Padded", "Fabric": "Cotton", "Type": "T-Shirt Bra"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Self Design", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Underwire", "Straps": "Regular", "Cup Type": "Non-Padded", "Fabric": "Polymide Net", "Type": "Plunge Bra"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Underwire", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non padded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Lycra Polymade", "Wire Support": "Underwire", "Detachable Straps": "Yes", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cup", "Fabric": "Lycra Polymade", "Type": "Push-up Bra"}
# {"Brand Color": "White, Black, Beige", "color": "White, Black, Beige", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Underwire", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non padded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "White, Blue", "color": "White", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Closure": "Hook", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton Lycra", "Seam Type": "Seamed", "Type": "Full Coverage Bra", "Series": "Delite", "Neck": "Round Neck", "Back": "Racer"}
# {"Brand Color": "Light Blue", "color": "Light Blue", "Pattern": "Floral Print", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Hosiery, Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Black, Purple", "color": "Black, Purple", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Hosiery", "Type": "Push-up Bra"}
# {"Brand Color": "Black, Cream, Dark Pink", "color": "Multicolor", "Pattern": "Solid", "Occasion": "Wedding, Casual, Party, Formal", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Fabric": "Silk", "Type": "Full Coverage Bra"}
# {"Brand Color": "Black", "color": "Black", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Moulded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Blue", "color": "Blue", "Pattern": "Polka Print", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Yes", "Wire Support": "Underwire", "Detachable Straps": "Yes", "Straps": "Multiway", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Seam Type": "Seamless", "Type": "T-Shirt Bra", "Design": "Polka Print"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Printed", "Occasion": "Casual, Festive, Formal", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "Yes", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "100% Cotton", "Seam Type": "Seamed", "Type": "Full Coverage Bra"}
# {"Brand Color": "Maroon, Black", "color": "Maroon, Black", "Ideal For": "Women's", "Occasion": "Formal", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Type": "T-Shirt Bra", "Series": "Women's"}
# {"Brand Color": "Purple, Red, Black", "color": "Purple, Red, Black", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Strapless", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Molded Cups", "Fabric": "Cotton Spandex", "Type": "Tube Bra"}
# {"Brand Color": "Blue, White", "color": "Multicolor", "Pattern": "Polka Print", "Occasion": "Casual, Beach Wear, Lounge Wear", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton Lycra", "Seam Type": "Seamed", "Type": "Full Coverage Bra"}
# {"Brand Color": "Pink, Maroon, Light Pink", "color": "Pink, Maroon, Pink", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Pink", "color": "Pink", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Blended Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Padded Cups", "Fabric": "Blended", "Type": "Sports Bra"}
# {"Brand Color": "White", "color": "White", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Beach Wear, Lounge Wear, Casual", "Wire Support": "Wirefree", "Closure": "Hook", "Straps": "Strapless", "Detachable Straps": "Yes", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton Lycra", "Type": "Tube Bra", "Seam Type": "Seamless", "Series": "Fashion", "Neck": "V Neck"}
# {"Brand Color": "lavender-Black", "color": "Purple, Black", "Pattern": "Floral Print", "Occasion": "Party, Wedding, Festive", "Ideal For": "Women's", "Inner Lining": "Cotton Lining inside of the cups", "Wire Support": "Wirefree", "Knit Type": "Lacy Bra Knit", "Closure": "Hook", "Detachable Straps": "No", "Fastening": "Provided at the Hooks at Back", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "not moulded", "Fabric": "Nylon lace", "Seam Type": "Seamed", "Type": "Full Coverage Bra", "Style": "Stretch Nylon Lace", "Neck": "V-Neck", "Back": "Hooked"}
# {"Brand Color": "Orange", "color": "Red, Pink, Orange", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Molded Cups", "Fabric": "Cotton Lycra", "Seam Type": "Seamed", "Type": "Full Coverage Bra"}
# {"Brand Color": "Blue", "color": "Blue", "Pattern": "Solid", "Occasion": "Party", "Ideal For": "Women's", "Inner Lining": "polyamide", "Wire Support": "Underwire", "Other Bra Details": "Fornt Open Bra - Easy to Wear and Remove", "Detachable Straps": "Yes", "Straps": "Multiway", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Pushup padded Cups", "Fabric": "85% Polyamide,15% Spandex", "Seam Type": "Seamless", "Type": "Push-up Bra", "Design": "Front open Pushup Balconette Underwire Bra -Get SEXIER Cleavage."}
# {"Brand Color": "White", "color": "White", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Blue", "color": "Blue", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Underwire", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Padded", "Fabric": "Nylon", "Type": "Push-up Bra", "Series": "Women's"}
# {"Brand Color": "Maroon", "color": "Maroon", "Pattern": "Striped", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "Yes", "Straps": "Multiway", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Moulded Seamless Cups", "Fabric": "Cotton Poly", "Type": "Full Coverage Bra"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Solid", "Occasion": "Casual, Party, Wedding", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Seam Type": "Seamless", "Type": "Full Coverage Bra"}
# {"Brand Color": "Beige", "color": "Beige", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Underwire", "Knit Type": "Single Jersey Knit", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra", "Neck": "Round Neck"}
# {"Brand Color": "Pink", "color": "Pink", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Closure": "Hook", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "85% Polyster ,15% Spandex", "Seam Type": "Seamed", "Type": "Push-up Bra", "Design": "Our most heavenly Push Up Bra ever from PrettySecrets! This bra features striking shimmer lace which is dazzling enough to make heads turn. With super soft cup lining and comfortable straps, this incredible push-up gives you the ultimate combination of comfort with style.\u2022Extreme lift, Add 2 cups\u2022Un...View More Our most heavenly Push Up Bra ever from PrettySecrets! This bra features striking shimmer lace which is dazzling enough to make heads turn. With super soft cup lining and comfortable straps, this incredible push-up gives you the ultimate combination of comfort with style.\u2022Extreme lift, Add 2 cups\u2022Underwired, Padded cups\u2022Adjustable and Removable Straps\u2022Convertible style: Strapless, Racer-back, Halter\u20222 rows of hook and eye closure\u2022Shimmer Scalloped Black lace on cups\u2022Centre front bow with pearl drop\u2022Polyester SpandexModel is wearing size 34C", "Back": "Hooked", "Wire Support": "Underwire", "Detachable Straps": "Yes", "Fastening": "Provided at the Hooks at Back", "Straps": "Multiway", "Cup Type": "Padded Cups", "Series": "Women's"}
# {"Brand Color": "Rani", "color": "Pink", "Pattern": "Solid", "Occasion": "Casual, Festive, Formal", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "Yes", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "100% Cotton", "Seam Type": "Seamed", "Type": "Full Coverage Bra"}
# {"Brand Color": "Black, Yellow", "color": "Black, Yellow", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non-Padded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Blue", "color": "Blue", "Pattern": "Printed", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Hosiery, Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "White", "color": "White", "Pattern": "Solid", "Occasion": "Casual, Party, Wedding", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Seam Type": "Seamless", "Type": "Full Coverage Bra"}
# {"Brand Color": "White", "color": "White", "Pattern": "Solid", "Occasion": "Casual, Party", "Ideal For": "Women's", "Wire Support": "Wirefree", "Other Bra Details": "Type: T-Shirt Bra, Full Coverage,Closure: Hook", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "Hosiery", "Type": "Full Coverage, T-Shirt Bra"}
# {"Brand Color": "Multicolor", "color": "Multicolor", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Fabric": "Cotton", "Type": "Minimizer Bra"}
# {"Brand Color": "Beige", "color": "Beige", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Moulded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Embroidered", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Underwire", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra", "Seam Type": "Seamed", "Back": "Hooked"}
# {"Brand Color": "Red, Pink, Purple", "color": "Red, Pink, Purple", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Orange, Grey", "color": "Orange, Grey", "Pattern": "Printed", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Red, Grey", "color": "Red, Grey", "Pattern": "Printed", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "White", "color": "White", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Yellow", "color": "Yellow", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Strapless", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Moulded Cups", "Fabric": "Cotton Spandex", "Type": "Tube Bra"}
# {"Brand Color": "Beige", "color": "Beige", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Seam Type": "Seamed", "Type": "Full Coverage Bra", "Series": "Women's", "Back": "Hooked"}
# {"Brand Color": "Beige", "color": "Red, Beige, Blue, Purple, Pink, Green", "Pattern": "Printed", "Ideal For": "Girl's", "Occasion": "Wedding, Party, Casual, Formal", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Fabric": "Cotton", "Type": "Full Coverage Bra", "Seam Type": "Seamed"}
# {"Brand Color": "Purple", "color": "Purple", "Pattern": "Polka Print", "Occasion": "Beach Wear", "Ideal For": "Women's", "Inner Lining": "Polyster Seamless Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Multiway", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Removable Soft Padded Cups", "Fabric": "Organic Cotton", "Seam Type": "Seamed", "Type": "Push-up Bra"}
# {"Brand Color": "Beige", "color": "Beige", "Pattern": "Solid", "Occasion": "Sports", "Ideal For": "Women's", "Inner Lining": "Polyamide", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Strapless", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "Polyamide", "Type": "Tube Bra"}
# {"Brand Color": "Red", "color": "Red", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Blue", "color": "Blue", "Pattern": "Self Design", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Closure": "Hook", "Straps": "Regular", "Fastening": "Provided at the Hooks at Back", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Lace Hoisery", "Type": "Full Coverage Bra", "Seam Type": "Seamed", "Series": "Basic", "Back": "Racer"}
# {"Brand Color": "Black, White, Pink", "color": "Multicolor", "Pattern": "Solid", "Occasion": "Wedding, Casual, Party, Formal", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Fabric": "Silk", "Type": "Full Coverage Bra"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Self Design", "Occasion": "Wedding", "Ideal For": "Women's", "Wire Support": "Wirefree", "Closure": "Hook", "Fastening": "Provided at the Hooks at Back", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton and Lace", "Type": "Balconette Bra", "Style": "High Quality imported Lace", "Series": "Net", "Neck": "Round Neck", "Back": "Racer"}
# {"Brand Color": "Beige", "color": "Beige", "Pattern": "Printed", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Underwire", "Detachable Straps": "Yes", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton Mix", "Seam Type": "Seamless", "Type": "T-Shirt Bra"}
# {"Brand Color": "Blue", "color": "Blue, Pink", "Pattern": "Striped", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Molded Cups", "Fabric": "Cotton Lycra", "Seam Type": "Seamed", "Type": "Full Coverage Bra"}
# {"Brand Color": "Purple", "color": "Purple", "Pattern": "Self Design", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Hosiery, Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Maroon", "color": "Maroon", "Pattern": "Solid, Self Design", "Ideal For": "Women's", "Occasion": "Casual, Party, Wedding", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra", "Seam Type": "Seamless"}
# {"Brand Color": "Multicolor", "color": "Red, White, Pink", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Inner Lining": "Polyster Seamless Lining", "Closure": "Closure Tube Bra", "Number of Contents in Sales Package": "Pack of 3", "Fabric": "Poly Lycra", "Seam Type": "Seamless", "Type": "Tube Bra", "Style": "Tube Bra Free Size fits bust Inch 28 - 38", "Neck": "Neck Less", "Back": "Racer", "Wire Support": "Wirefree", "Fastening": "Provided at the No Hooks", "Straps": "Regular", "Detachable Straps": "No", "Cup Type": "Non Padded", "Series": "Women's", "Weave Type": "Polyster Weave"}
# {"Brand Color": "White", "color": "White", "Pattern": "Polka Print", "Ideal For": "Women's", "Occasion": "Beach Wear, Lounge Wear, Casual", "Wire Support": "Wirefree", "Closure": "Hook", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton Lycra", "Type": "Full Coverage Bra", "Seam Type": "Seamed", "Series": "Fashion", "Neck": "V Neck"}
# {"Brand Color": "Purple", "color": "Purple", "Pattern": "Striped", "Ideal For": "Women's", "Occasion": "Formal", "Wire Support": "Underwire", "Inner Lining": "Polycotton", "Straps": "Multiway", "Detachable Straps": "Yes", "Other Bra Details": "Perfect T-Shirt Bra", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Soft Padded Molded Cups", "Fabric": "Polycotton,Elastane", "Type": "T-Shirt Bra", "Seam Type": "Seamless", "Design": "Plung Neck Balconette Underwire Bra"}
# {"Brand Color": "Cherry, Green", "color": "Multicolor", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Hosiery Lining", "Wire Support": "Wirefree", "Other Bra Details": "Product\u00a0Colour\u00a0May\u00a0Slightly\u00a0Vary Due To Photographic Lighting\u00a0Sources.", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Molded Cups", "Fabric": "Hosiery", "Seam Type": "Seamless", "Type": "Full Coverage Bra", "Design": "Logo Print At Underbust"}
# {"Brand Color": "Purple", "color": "Purple", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Blended Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Padded Cups", "Fabric": "Blended", "Type": "Sports Bra"}
# {"Brand Color": "Pink", "color": "Pink", "Pattern": "Solid", "Occasion": "Wedding", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Lycra Lace", "Seam Type": "Seamed", "Type": "Full Coverage Bra"}
# {"Brand Color": "Pink, Green, Light Blue", "color": "Pink, Green, Light Blue", "Pattern": "Floral Print", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Hosiery, Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "White", "color": "White", "Pattern": "Self Design", "Ideal For": "Women's", "Occasion": "Beach Wear, Lounge Wear, Casual", "Wire Support": "Wirefree", "Closure": "Hook", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton Hosiery", "Type": "Full Coverage Bra", "Seam Type": "Seamed", "Series": "Fashion", "Neck": "V Neck"}
# {"Brand Color": "Purple", "color": "Purple", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Padded", "Fabric": "Nylon/ Spandex", "Type": "T-Shirt Bra", "Series": "Women's"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Underwire", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Other Bra Details": "Florentyne Padded Push-up Bra is padded with soft pads inbuild with depth from bottom that provides push up support which enhances the shape and it has underwire support too. It has satin lace outlined at border of cups with cute bow in centre that complements its look", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Padded Cups", "Fabric": "Cotton", "Type": "Push-up Bra", "Seam Type": "Seamless"}
# {"Brand Color": "Black", "color": "Black", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Strapless", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Moulded Cups", "Fabric": "Cotton Spandex", "Type": "Tube Bra"}
# {"Brand Color": "Multicolor", "color": "Multicolor", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Knit Type": "Single Jersey Knit", "Wire Support": "Underwire", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra", "Neck": "Round Neck"}
# {"Brand Color": "Maroon", "color": "Maroon", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Pink, Purple, Light Pink", "color": "Pink, Purple, Pink", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "White", "color": "White", "Pattern": "Solid", "Occasion": "Wedding, Beach Wear, Casual, Festive, Lounge Wear, Party", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "Yes", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Nylon", "Seam Type": "Seamless", "Type": "Full Coverage Bra"}
# {"Brand Color": "Pink", "color": "Pink", "Pattern": "Solid", "Occasion": "Party, Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Other Bra Details": "Type: T-Shirt Bra, Full Coverage,Closure: Hook", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "Hosiery", "Type": "Full Coverage, T-Shirt Bra"}
# {"Brand Color": "White", "color": "White", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Dark Grey", "color": "Grey", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Multiway", "Detachable Straps": "Yes", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Length": "22 inch", "Brand Color": "Pink", "color": "Pink", "Pattern": "Animal Print", "Occasion": "Wedding", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Knit Type": "Jersey Knit", "Closure": "Hook", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "Velvet", "Type": "Push-up Bra", "Seam Type": "Seamed", "Style": "Animal Print Style", "Neck": "V neck", "Back": "Hooked", "Design": "Animal Print", "Wire Support": "Underwire", "Other Bra Details": "Dummy, Dummy", "Detachable Straps": "Yes", "Straps": "Regular", "Fastening": "Provided at the Hooks at Back", "Cup Type": "Padded Cups", "Sheerness": "Plain Straps", "Series": "Women's", "Weave Type": "Velvet Weave"}
# {"Brand Color": "Green, Blue", "color": "Green, Blue", "Ideal For": "Women's", "Occasion": "Formal", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Type": "T-Shirt Bra", "Series": "Women's"}
# {"Brand Color": "Powder Blue", "color": "Light Blue", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Regular", "Other Bra Details": "NA", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "White", "color": "White", "Ideal For": "Women's", "Occasion": "Casual", "Knit Type": "Cotton spandex Knit", "Closure": "Hook at Back", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "Cotton Spandex", "Seam Type": "Seamless", "Type": "Minimizer Bra", "Style": "95% COTTON 5% SPANDEX", "Neck": "Full cup round neck", "Back": "Hooked", "Wire Support": "Wirefree", "Fastening": "Provided at the Hooks at Back", "Straps": "Regular", "Detachable Straps": "Yes", "Cup Type": "Molded Cotton", "Series": "Women's"}
# {"Brand Color": "Yellow", "color": "Yellow", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "White", "color": "White", "Pattern": "Self Design", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Underwire", "Straps": "Regular", "Cup Type": "Non-Padded", "Fabric": "Polymide Net", "Type": "Plunge Bra"}
# {"Brand Color": "Mauve", "Age Group": "NA - NA month", "color": "Purple", "Pattern": "Printed", "Occasion": "Casual, Festive, Formal", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "Yes", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "100% Cotton", "Seam Type": "Seamed", "Type": "Full Coverage Bra"}
# {"Brand Color": "Beige", "color": "Beige", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Underwire", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Nylon", "Type": "Full Coverage Bra", "Series": "Women's"}
# {"Brand Color": "White", "Age Group": "NA - NA month", "color": "White", "Pattern": "Solid", "Occasion": "Casual, Party", "Ideal For": "Women's", "Wire Support": "Wirefree", "Other Bra Details": "Type: T-Shirt Bra, Full Coverage,Closure: Hook", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "Hosiery", "Type": "Full Coverage, T-Shirt Bra"}
# {"Brand Color": "Beige", "color": "Beige", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual, Party", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Other Bra Details": "Type: T-Shirt Bra, Full Coverage,Closure: Hook", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "Hosiery", "Type": "Full Coverage, T-Shirt Bra"}
# {"Brand Color": "Red", "color": "Red", "Pattern": "Printed", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Hosiery, Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Multicolor", "color": "Pink, Black", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Inner Lining": "Polyster Seamless Lining", "Closure": "Closure Tube Bra", "Number of Contents in Sales Package": "Pack of 2", "Fabric": "Poly Lycra", "Seam Type": "Seamless", "Type": "Tube Bra", "Style": "Tube Bra Free Size fits bust Inch 28 - 38", "Neck": "Neck Less", "Back": "Racer", "Wire Support": "Wirefree", "Detachable Straps": "No", "Fastening": "Provided at the No Hooks", "Straps": "Regular", "Cup Type": "Non Padded", "Series": "Women's", "Weave Type": "Polyster Weave"}
# {"Brand Color": "Pink", "color": "Pink", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Blended Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Padded Cups", "Fabric": "Blended", "Type": "Sports Bra"}
# {"Brand Color": "Pink, Yellow, Orange", "color": "Pink, Yellow, Orange", "Pattern": "Floral Print", "Ideal For": "Women's", "Occasion": "Party", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Other Bra Details": "Coloured Bra, Panty", "Number of Contents in Sales Package": "Pack of 3", "Fabric": "Cotton", "Type": "Full Coverage Bra", "Seam Type": "Seamed"}
# {"Brand Color": "Pink", "color": "Pink", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Strapless", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Polyester Blend", "Seam Type": "Seamless", "Type": "Tube Bra", "Series": "Women's"}
# {"Brand Color": "White, Blue", "color": "Multicolor", "Pattern": "Polka Print, Solid", "Occasion": "Beach Wear, Lounge Wear, Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Closure": "Hook", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton hosiery, Cotton Lycra", "Seam Type": "Seamed", "Type": "Full Coverage Bra", "Series": "Fashion", "Neck": "V Neck"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Floral Print", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Underwire", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Black Multi", "color": "Multicolor", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Padded", "Fabric": "Nylon", "Type": "Push-up Bra", "Series": "Women's"}
# {"Brand Color": "Red, Orange, Chocolate", "color": "Red, Orange, Brown", "Pattern": "Printed", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Pink", "color": "Pink", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Blended Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Padded Cups", "Fabric": "Blended", "Type": "Sports Bra"}
# {"Brand Color": "Purple", "color": "Purple", "Pattern": "Self Design", "Occasion": "Formal", "Ideal For": "Women's", "Inner Lining": "Polyamide", "Wire Support": "Underwire", "Other Bra Details": "Perfect T-SHIRT BRA, Kurta Bra", "Detachable Straps": "Yes", "Straps": "Multiway", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "soft padded cups", "Fabric": "Polyamide, elastane", "Seam Type": "Seamless", "Type": "T-Shirt Bra", "Design": "Self Design Padded Underwire Bra"}
# {"Brand Color": "Grey", "color": "Grey", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Underwire", "Detachable Straps": "Yes", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton Mix", "Seam Type": "Seamless", "Type": "T-Shirt Bra"}
# {"Brand Color": "Beige", "color": "Beige", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Underwire", "Knit Type": "Single Jersey Knit", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra", "Neck": "Round Neck"}
# {"Brand Color": "White", "color": "White", "Pattern": "Embroidered", "Ideal For": "Women's", "Occasion": "Beach Wear, Lounge Wear, Casual", "Wire Support": "Wirefree", "Closure": "Hook", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Chikan Cotton", "Type": "Full Coverage Bra", "Seam Type": "Seamed", "Series": "Fashion", "Neck": "V Neck"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra", "Seam Type": "Seamed", "Back": "Hooked"}
# {"Brand Color": "White", "color": "White", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual, Party", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Other Bra Details": "Type: T-Shirt Bra, Full Coverage, Closure: Hook", "Number of Contents in Sales Package": "Pack of 1", "Fabric": "Cotton", "Type": "Full Coverage, T-Shirt Bra"}
# {"Brand Color": "Light Pink, Yellow", "color": "Pink, Yellow", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Purple", "color": "Purple", "Pattern": "Animal Print", "Ideal For": "Women's", "Occasion": "Wedding", "Wire Support": "Underwire", "Inner Lining": "Polyamide", "Straps": "Multiway", "Detachable Straps": "Yes", "Other Bra Details": "T-Shirt Bra", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Thick Padded Cups", "Fabric": "Polyamide", "Type": "Push-up Bra", "Seam Type": "Seamless", "Design": "Enhance the Cleavage-Thick Pushup Underwire bra . Detachable straps to wear it criss-cross way ."}
# {"Brand Color": "Black, White", "color": "Black, White", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Regular", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Solid", "Occasion": "Casual, Party", "Ideal For": "Women's", "Wire Support": "Wirefree", "Other Bra Details": "Type: T-Shirt Bra, Full Coverage,Closure: Hook", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Padded", "Fabric": "Hosiery", "Type": "T-Shirt Bra"}
# {"Brand Color": "Rust", "color": "Orange", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual, Festive, Formal", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "Yes", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "100% Cotton", "Type": "Full Coverage Bra", "Seam Type": "Seamed"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Strapless", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Polyester Blend", "Type": "Tube Bra"}
# {"Brand Color": "Red", "color": "Red", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Pink", "color": "Pink", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Detachable Straps": "No", "Fastening": "Provided at the Hooks at Back", "Straps": "Multiway", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Seam Type": "Seamless", "Type": "Full Coverage Bra", "Back": "Hooked"}
# {"Brand Color": "Pink, Orange, Purple", "color": "Pink, Purple, Orange", "Pattern": "Printed", "Occasion": "Formal, Casual, Party", "Ideal For": "Women's", "Inner Lining": "Cotton Linning", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Regular Cup", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "White", "color": "White", "Pattern": "Embroidered", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Other Bra Details": "Non Padded", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Regular", "Fabric": "Cotton", "Type": "Balconette Bra"}
# {"Brand Color": "Pink, Purple", "color": "Pink, Purple", "Pattern": "Self Design", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Hosiery, Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Red", "color": "Red", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Grey", "color": "Grey", "Pattern": "Solid", "Occasion": "Party, Casual, Beach Wear, Wedding", "Ideal For": "Women's", "Inner Lining": "Spandex", "Wire Support": "Wirefree", "Detachable Straps": "Yes", "Straps": "Strapless", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Spandex", "Type": "Plunge Bra"}
# {"Brand Color": "Multicolor", "color": "Multicolor", "Pattern": "Solid", "Occasion": "Wedding, Casual, Party, Formal", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Fabric": "Silk", "Type": "Full Coverage Bra"}
# {"Brand Color": "Pink, Purple, Yellow", "color": "Pink, Purple, Yellow", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Black", "color": "Black", "Pattern": "Polka Print", "Ideal For": "Women's", "Occasion": "Formal", "Wire Support": "Underwire", "Inner Lining": "Polyamide", "Straps": "Multiway", "Detachable Straps": "Yes", "Other Bra Details": "Perfect T-Shirt Bra -Seamless", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Soft Molded Cups", "Fabric": "80% Polyamide, 20% Elastane", "Type": "T-Shirt Bra", "Seam Type": "Seamless", "Design": "Vibrnat Color polka Prints seamless Underwire Bra"}
# {"Brand Color": "Purple, Pink", "color": "Purple, Pink", "Pattern": "Self Design", "Ideal For": "Women's", "Occasion": "Formal", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Lycra Lace", "Type": "Full Coverage Bra", "Seam Type": "Seamed"}
# {"Brand Color": "Maroon", "color": "Maroon", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Blue", "color": "Blue", "Pattern": "Polka Print", "Occasion": "Casual", "Ideal For": "Women's", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Hosiery", "Type": "Full Coverage Bra"}
# {"Brand Color": "White", "color": "White", "Ideal For": "Women's", "Wire Support": "Wirefree", "Closure": "Hooked", "Straps": "Regular", "Fastening": "Provided at the Hooked", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "95% Cotton 5% Spandex", "Type": "Full Coverage Bra", "Seam Type": "Seamed", "Series": "Women's", "Back": "Hooked"}
# {"Brand Color": "White", "color": "White", "Pattern": "Solid", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Soft Cup", "Fabric": "Cotton", "Seam Type": "Seamed", "Type": "Full Coverage Bra"}
# {"Brand Color": "Green, Light Blue", "color": "Green, Light Blue", "Pattern": "Floral Print", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Hosiery, Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Red", "color": "Red", "Pattern": "Polka Print", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Underwire", "Straps": "Regular", "Cup Type": "Padded", "Fabric": "Polymide Net", "Type": "Plunge Bra"}
# {"Brand Color": "White", "color": "White", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Maroon", "color": "Red", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Padded cups", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Black, Grey", "color": "Black, Grey", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Purple, Light Pink, Yellow", "color": "Purple, Pink, Yellow", "Pattern": "Solid", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 3", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "Yellow", "color": "Yellow", "Pattern": "Self Design", "Occasion": "Wedding", "Ideal For": "Women's", "Inner Lining": "Polyamide", "Wire Support": "Underwire", "Other Bra Details": "Perfect Pushup T-SHIRT Bra", "Detachable Straps": "Yes", "Straps": "Multiway", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Pushup Paded Cups", "Fabric": "80% Polyamide,20% Elastane", "Seam Type": "Seamless", "Type": "Push-up Bra", "Design": "Breathable airy Fabric . Pushup ,Underwire Bra"}
# {"Brand Color": "Beige", "color": "Beige", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded Cups", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Turquise", "color": "Blue", "Pattern": "Polka Print", "Occasion": "Party", "Ideal For": "Women's", "Inner Lining": "Lycra Polymade", "Wire Support": "Underwire", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Molded", "Fabric": "Lycra Polymade", "Type": "Push-up Bra"}
# {"Brand Color": "Blue, Red", "color": "Blue, Red", "Pattern": "Printed", "Ideal For": "Women's", "Occasion": "Casual", "Wire Support": "Wirefree", "Inner Lining": "Cotton Lining", "Straps": "Regular", "Detachable Straps": "No", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Hosiery, Cotton", "Type": "Full Coverage Bra"}
# {"Brand Color": "Pink, Orange", "color": "Pink, Orange", "Pattern": "Printed", "Occasion": "Casual", "Ideal For": "Women's", "Inner Lining": "Cotton Lining", "Wire Support": "Wirefree", "Detachable Straps": "No", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 2", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Push-up Bra"}
# {"Brand Color": "White", "color": "White", "Ideal For": "Women's", "Wire Support": "Wirefree", "Straps": "Regular", "Number of Contents in Sales Package": "Pack of 1", "Cup Type": "Non Padded", "Fabric": "Cotton", "Type": "Full Coverage Bra"}
# ...
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Brand": "Wallmantra", "Shape": "Rectangular", "Scratch-resistant": "No", "Laminated": "No", "Type": "Vinyl Stickers", "Number of Stickers": "1", "Size in Number": "45 cm", "Material": "Vinyl", "Size": "Medium", "Weight": "200 g", "Height": "45 cm", "Width": "45 cm"}
# {"Occasion": "Party", "Ideal For": "Women", "Type": "Heels", "Heel Height": "3 inch", "Outer Material": "Synthetic Leather", "Color": "Red"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Scratch-resistant": "No", "Shape": "Rectangular", "Brand": "Wallmantra", "Laminated": "No", "Type": "Vinyl Stickers", "Size in Number": "60 cm", "Number of Stickers": "1", "Material": "Vinyl", "Size": "Large", "Weight": "200 g", "Height": "78 cm", "Width": "60 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "3D Acrylic Wall Decor Decal, Self Adhesive Tape", "Ideal Use": "Wall", "Brand": "Elite Collection", "Scratch-resistant": "No", "Type": "Acrylic", "Number of Stickers": "8", "Size in Number": "0.2 cm", "Size": "Medium", "Weight": "500 g", "Thickness": "0.2 cm"}
# {"Sales Package": "Wall Sticker", "Brand": "999store", "Shape": "Rectangular", "Type": "Paper", "Number of Stickers": "1", "Size in Number": "91 cm", "Size": "Medium"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Scratch-resistant": "No", "Shape": "Rectangular", "Brand": "Wallmantra", "Laminated": "No", "Type": "Vinyl Stickers", "Size in Number": "83 cm", "Number of Stickers": "1", "Material": "Vinyl", "Size": "Large", "Height": "83 cm", "Width": "75 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Brand": "Wallmantra", "Shape": "Rectangular", "Scratch-resistant": "No", "Laminated": "No", "Type": "Vinyl Stickers", "Number of Stickers": "1", "Size in Number": "120 cm", "Material": "Vinyl", "Size": "Extra Large", "Weight": "200 g", "Height": "93 cm", "Width": "120 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Brand": "Wallmantra", "Shape": "Rectangular", "Scratch-resistant": "No", "Laminated": "No", "Type": "Vinyl Stickers", "Number of Stickers": "1", "Size in Number": "60 cm", "Material": "Vinyl", "Size": "Extra Large", "Weight": "200 g", "Height": "123 cm", "Width": "60 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Brand": "Wallmantra", "Shape": "Rectangular", "Scratch-resistant": "No", "Laminated": "No", "Type": "Vinyl Stickers", "Number of Stickers": "1", "Size in Number": "75 cm", "Material": "Vinyl", "Size": "Extra Large", "Weight": "200 g", "Height": "78 cm", "Width": "75 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Scratch-resistant": "No", "Shape": "Rectangular", "Brand": "Wallmantra", "Laminated": "No", "Type": "Vinyl Stickers", "Size in Number": "145 cm", "Number of Stickers": "1", "Material": "Vinyl", "Size": "Extra Large", "Height": "145 cm", "Width": "105 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Scratch-resistant": "No", "Shape": "Rectangular", "Brand": "Wallmantra", "Laminated": "No", "Type": "Vinyl Stickers", "Size in Number": "68 cm", "Number of Stickers": "1", "Material": "Vinyl", "Size": "Medium", "Weight": "200 g", "Height": "35 cm", "Width": "68 cm"}
# {"Number of Contents in Sales Package": "Pack of 52", "Sales Package": "Sticker", "Ideal Use": "Wall Decoration, Home D\u00e9cor, Furniture, Door, Bedroom, Living Room, Kids Room", "Brand": "WallDesign", "Shape": "Aeroplane", "Scratch-resistant": "Yes", "Theme": "Aeroplanes, Kids", "Laminated": "Yes", "Type": "Vinyl", "Number of Stickers": "52", "Size in Number": "4.5 inch", "Ideal For": "Home d\u00e9cor, Wall Decoration, Living Room, Bedroom:Bathroom, Kitchen", "Size": "Small", "Design": "Aeroplanes, Kids", "Height": "12.5 cm", "Width": "11.25 cm", "Thickness": "0.1 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Scratch-resistant": "No", "Shape": "Rectangular", "Brand": "Wallmantra", "Laminated": "No", "Type": "Vinyl Stickers", "Size in Number": "90 cm", "Number of Stickers": "1", "Material": "Vinyl", "Size": "Large", "Weight": "200 g", "Height": "48 cm", "Width": "90 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Brand": "Wallmantra", "Shape": "Rectangular", "Scratch-resistant": "No", "Laminated": "No", "Type": "Vinyl Stickers", "Number of Stickers": "1", "Size in Number": "108 cm", "Material": "Vinyl", "Size": "Extra Large", "Height": "108 cm", "Width": "90 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Scratch-resistant": "No", "Shape": "Rectangular", "Brand": "Wallmantra", "Laminated": "No", "Type": "Vinyl Stickers", "Size in Number": "60 cm", "Number of Stickers": "1", "Material": "Vinyl", "Size": "Extra Large", "Weight": "200 g", "Height": "65 cm", "Width": "60 cm"}
# {"Number of Contents in Sales Package": "Pack of 2", "Sales Package": "Sticker", "Brand": "Uberlyfe", "Type": "Vinyl", "Size in Number": "90 cm", "Number of Stickers": "2", "Material": "Vinyl", "Size": "Extra Large", "Height": "200 cm", "Width": "160 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Scratch-resistant": "No", "Shape": "Rectangular", "Brand": "Wallmantra", "Laminated": "No", "Type": "Vinyl Stickers", "Size in Number": "60 cm", "Number of Stickers": "1", "Material": "Vinyl", "Size": "Large", "Weight": "200 g", "Height": "70 cm", "Width": "60 cm"}
# {"Number of Contents in Sales Package": "Pack of 55", "Sales Package": "Sticker", "Ideal Use": "Wall Decoration, Home D\u00e9cor, Furniture, Door, Bedroom, Living Room, Kids Room", "Scratch-resistant": "Yes", "Shape": "Damask", "Brand": "WallDesign", "Laminated": "Yes", "Theme": "Royal, Damask", "Type": "Vinyl", "Size in Number": "4 inch", "Number of Stickers": "55", "Ideal For": "Home d\u00e9cor, Wall Decoration, Living Room, Bedroom:Bathroom, Kitchen", "Design": "Royal, Damask", "Size": "Small", "Height": "7.5 cm", "Width": "10 cm", "Thickness": "0.1 cm"}
# {"Number of Contents in Sales Package": "Pack of 118", "Sales Package": "Sticker", "Ideal Use": "Wall Decoration, Home D\u00e9cor, Furniture, Door, Bedroom, Living Room, Kids Room", "Brand": "WallDesign", "Shape": "Star", "Scratch-resistant": "Yes", "Theme": "Stars, Sky", "Laminated": "Yes", "Type": "Vinyl", "Number of Stickers": "118", "Size in Number": "3 inch", "Ideal For": "Home d\u00e9cor, Wall Decoration, Living Room, Bedroom:Bathroom, Kitchen", "Size": "Small", "Design": "Stars, Sky", "Height": "7.5 cm", "Width": "7.5 cm", "Thickness": "0.1 cm"}
# {"Number of Contents in Sales Package": "Pack of 75", "Sales Package": "Sticker", "Ideal Use": "Wall Decoration, Home D\u00e9cor, Furniture, Door, Bedroom, Living Room, Kids Room", "Brand": "WallDesign", "Shape": "Butterfly", "Scratch-resistant": "Yes", "Theme": "Butterfly, Butterflies, Nature", "Laminated": "Yes", "Type": "Vinyl", "Number of Stickers": "75", "Size in Number": "3 inch", "Ideal For": "Home d\u00e9cor, Wall Decoration, Living Room, Bedroom:Bathroom, Kitchen", "Size": "Small", "Design": "Butterfly, Butterflies, Nature", "Height": "6.75 cm", "Width": "7.5 cm", "Thickness": "0.1 cm"}
# {"Number of Contents in Sales Package": "Pack of 60", "Sales Package": "Sticker", "Ideal Use": "Wall Decoration, Home D\u00e9cor, Furniture, Door, Bedroom, Living Room, Kids Room", "Brand": "WallDesign", "Shape": "Star", "Scratch-resistant": "Yes", "Theme": "Star", "Laminated": "Yes", "Type": "Vinyl", "Number of Stickers": "60", "Size in Number": "3 inch", "Ideal For": "Home d\u00e9cor, Wall Decoration, Living Room, Bedroom:Bathroom, Kitchen", "Size": "Small", "Design": "Star", "Height": "7.5 cm", "Width": "7.5 cm", "Thickness": "0.1 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal/Sticker, 1 Practice Decal, Instructions", "Ideal Use": "Child Bedroom, Bedroom, Living Room", "Brand": "Wallmantra", "Shape": "Rectangular", "Scratch-resistant": "No", "Laminated": "Yes", "Type": "Vinyl Sticker", "Number of Stickers": "1", "Size in Number": "100 cm", "Material": "Vinyl", "Lamination Type": "Matte", "Size": "Large", "Height": "100 cm", "Width": "53 cm"}
# {"Sales Package": "Wall Sticker", "Shape": "Rectangular", "Brand": "999store", "Type": "Paper", "Size in Number": "91 cm", "Number of Stickers": "1", "Size": "Medium"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "3D Acrylic Wall Decor Decal, Self Adhesive Tape", "Ideal Use": "Wall", "Scratch-resistant": "No", "Brand": "Elite Collection", "Type": "Acrylic", "Size in Number": "0.2 cm", "Number of Stickers": "11", "Size": "Medium", "Weight": "500 g", "Thickness": "0.2 cm"}
# {"Sales Package": "Wall Sticker", "Shape": "Rectangular", "Brand": "999store", "Type": "Paper", "Size in Number": "91 cm", "Number of Stickers": "1", "Size": "Medium"}
# {"Number of Contents in Sales Package": "Pack of 75", "Sales Package": "Sticker", "Ideal Use": "Wall Decoration, Home D\u00e9cor, Furniture, Door, Bedroom, Living Room, Kids Room", "Scratch-resistant": "Yes", "Shape": "Butterfly", "Brand": "WallDesign", "Laminated": "Yes", "Theme": "Butterfly, Butterflies, Nature", "Type": "Vinyl", "Size in Number": "3 inch", "Number of Stickers": "75", "Ideal For": "Home d\u00e9cor, Wall Decoration, Living Room, Bedroom:Bathroom, Kitchen", "Design": "Butterfly, Butterflies, Nature", "Size": "Small", "Height": "6.75 cm", "Width": "7.5 cm", "Thickness": "0.1 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Brand": "Wallmantra", "Shape": "Rectangular", "Scratch-resistant": "No", "Laminated": "No", "Type": "Vinyl Stickers", "Number of Stickers": "1", "Size in Number": "75 cm", "Material": "Vinyl", "Size": "Extra Large", "Weight": "200 g", "Height": "75 cm", "Width": "75 cm"}
# {"Number of Contents in Sales Package": "Pack of 60", "Sales Package": "Sticker", "Ideal Use": "Wall Decoration, Home D\u00e9cor, Furniture, Door, Bedroom, Living Room, Kids Room", "Scratch-resistant": "Yes", "Shape": "Lotus", "Brand": "WallDesign", "Laminated": "Yes", "Theme": "Lotus, Nature", "Type": "Vinyl", "Size in Number": "3.75 inch", "Number of Stickers": "60", "Ideal For": "Home d\u00e9cor, Wall Decoration, Living Room, Bedroom:Bathroom, Kitchen", "Design": "Lotus, Nature", "Size": "Small", "Height": "6.5 cm", "Width": "9.375 cm", "Thickness": "0.1 cm"}
# {"Sales Package": "Wall Sticker", "Shape": "Rectangular", "Brand": "999store", "Type": "Paper", "Size in Number": "91 cm", "Number of Stickers": "1", "Size": "Medium"}
# {"Number of Contents in Sales Package": "Pack of 8", "Sales Package": "3D Acrylic Wall Decor Decal, Self Adhesive Tape, Installation Guide", "Ideal Use": "Wall", "Scratch-resistant": "No", "Brand": "Elite Collection", "Type": "Acrylic", "Size in Number": "0.2 cm", "Number of Stickers": "8", "Size": "Medium", "Weight": "500 g", "Thickness": "0.2 cm"}
# {"Number of Contents in Sales Package": "Pack of 75", "Sales Package": "Sticker", "Ideal Use": "Wall Decoration, Home D\u00e9cor, Furniture, Door, Bedroom, Living Room, Kids Room", "Brand": "WallDesign", "Shape": "Butterfly", "Scratch-resistant": "Yes", "Theme": "Butterfly, Butterflies, Nature", "Laminated": "Yes", "Type": "Vinyl", "Number of Stickers": "75", "Size in Number": "3 inch", "Ideal For": "Home d\u00e9cor, Wall Decoration, Living Room, Bedroom:Bathroom, Kitchen", "Size": "Small", "Design": "Butterfly, Butterflies, Nature", "Height": "6.75 cm", "Width": "7.5 cm", "Thickness": "0.1 cm"}
# {"Sales Package": "Wall Sticker", "Shape": "Rectangular", "Brand": "999store", "Type": "Paper", "Size in Number": "91 cm", "Number of Stickers": "1", "Size": "Medium"}
# {"Number of Contents in Sales Package": "Pack of 20", "Sales Package": "3D Acrylic Wall Decor Decal, Self Adhesive Tape, Installation Guide", "Ideal Use": "Wall", "Brand": "Elite Collection", "Scratch-resistant": "No", "Type": "Acrylic", "Number of Stickers": "20", "Size in Number": "0.2 cm", "Size": "Medium", "Weight": "500 g", "Thickness": "0.2 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Brand": "Wallmantra", "Shape": "Rectangular", "Scratch-resistant": "No", "Laminated": "No", "Type": "Vinyl Stickers", "Number of Stickers": "1", "Size in Number": "53 cm", "Material": "Vinyl", "Size": "Large", "Weight": "200 g", "Height": "58 cm", "Width": "53 cm"}
# {"Number of Contents in Sales Package": "Pack of 55", "Sales Package": "Sticker", "Ideal Use": "Wall Decoration, Home D\u00e9cor, Furniture, Door, Bedroom, Living Room, Kids Room", "Scratch-resistant": "Yes", "Shape": "Damask", "Brand": "WallDesign", "Laminated": "Yes", "Theme": "Royal, Damask", "Type": "Vinyl", "Size in Number": "4 inch", "Number of Stickers": "55", "Ideal For": "Home d\u00e9cor, Wall Decoration, Living Room, Bedroom:Bathroom, Kitchen", "Design": "Royal, Damask", "Size": "Small", "Height": "7.5 cm", "Width": "10 cm", "Thickness": "0.1 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "1 Wall Decal, 2 Practise Decals, Instruction Manual", "Ideal Use": "Wall", "Brand": "Wallmantra", "Shape": "Rectangular", "Scratch-resistant": "No", "Laminated": "No", "Type": "Vinyl Stickers", "Number of Stickers": "1", "Size in Number": "75 cm", "Material": "Vinyl", "Size": "Large", "Weight": "200 g", "Height": "60 cm", "Width": "75 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "3D Acrylic Wall Decor Decal, Self Adhesive Tape", "Ideal Use": "Wall", "Scratch-resistant": "No", "Shape": "Fish", "Brand": "Elite Collection", "Type": "Acrylic", "Size in Number": "0.2 cm", "Number of Stickers": "5", "Size": "Medium", "Weight": "200 g", "Thickness": "0.2 cm"}
# {"Number of Contents in Sales Package": "Pack of 1", "Sales Package": "3D Acrylic Wall Decor Decal, Self Adhesive Tape", "Ideal Use": "Wall", "Scratch-resistant": "No", "Brand": "Elite Collection", "Type": "Acrylic", "Size in Number": "0.2 cm", "Number of Stickers": "8", "Size": "Medium", "Weight": "500 g", "Thickness": "0.2 cm"}
# {"Number of Contents in Sales Package": "Pack of 3", "Sales Package": "3D Acrylic Wall Decor Decal, Self Adhesive Tape, Installation Guide", "Ideal Use": "Wall", "Brand": "Elite Collection", "Scratch-resistant": "No", "Type": "Acrylic", "Number of Stickers": "3", "Size in Number": "0.2 cm", "Size": "Medium", "Weight": "500 g", "Thickness": "0.2 cm"}

# %%
df_with_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uniq_id                 20000 non-null  object
#  1   product_name            20000 non-null  object
#  2   description             20000 non-null  object
#  3   brand                   14136 non-null  object
#  4   image                   19997 non-null  object
#  5   product_specifications  19986 non-null  object
#  6   c0_name                 20000 non-null  object
#  7   c1_name                 19672 non-null  object
#  8   c2_name                 18543 non-null  object
#  9   c3_name                 14124 non-null  object
#  10  attributes              19986 non-null  object
# dtypes: object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# # Downloading Images from product image url into GCS

# %%
from google.cloud import storage
from google.cloud.storage import Bucket

IMAGE_BUCKET = 'genai-product-catalog'
GCS_IMAGE_FOLDER = 'flipkart_Nov14'

def create_gcs_bucket(bucket_name: str):
  storage_client = storage.Client()
  exists = Bucket(storage_client, IMAGE_BUCKET).exists()
  if exists:
    print("Bucket exists")
  else:
    print("Bucket does not exist")
    # Creates the new bucket
    bucket = storage_client.create_bucket(IMAGE_BUCKET)
    print(f"Bucket {bucket.name} created.")

# %%
create_gcs_bucket(IMAGE_BUCKET)
# Out:
# Bucket exists

# %%
import urllib.request, urllib.error
#from numpy import NaN

#Formating Imagelist string into list of image urls
def extract_url(image_list: str) -> List[str]:
  image_list = image_list.replace('[', '')
  image_list = image_list.replace(']', '')
  image_list = image_list.replace('"', '')
  #image_list = image_list.apply(lambda x: reformat(x))
  image_urls = image_list.split(',')
  return image_urls

#Dowlonding image from flipkart url into gcs bucket
def download_image(image_url, image_file_name, destination_blob_name):
  storage_client = storage.Client()
  image_found_flag = False
  try:
    urllib.request.urlretrieve(image_url, image_file_name)
    bucket = storage_client.bucket(IMAGE_BUCKET)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(image_file_name)
    print(
        f"File {image_file_name} uploaded to {destination_blob_name}."
    )
    image_found_flag = True
  except urllib.error.URLError:
    print("URLError exception")
  except urllib.error.HTTPError:
    print("HTTPError exception")
  except urllib.error.HTTPException:
    print("HTTPException exception")
  except:
    print("Unknown exception")
  return image_found_flag

# %%
#Get Image URI
def get_product_image(df):
  products_with_no_image_count = 0
  products_with_no_image = []
  gcs_image_url = []
  image_found_flag = False

  for id, image_list in zip(df['uniq_id'], df['image']):

    if pd.isnull(image_list): #No image url
      print("WARNING: No image url: product ", id)
      products_with_no_image_count += 1
      products_with_no_image.append(id)
      gcs_image_url.append(None)
      continue

    image_urls = extract_url(image_list)
    for index in range(len(image_urls)):
      image_url = image_urls[index]
      image_file_name = '{}_{}.jpg'.format(id, index)
      destination_blob_name = GCS_IMAGE_FOLDER+'/'+image_file_name
      image_found_flag = download_image(image_url, image_file_name, destination_blob_name)
      if image_found_flag:
        gcs_image_url.append('gs://'+IMAGE_BUCKET+'/'+destination_blob_name)
        break
    if not image_found_flag:
      print("WARNING: No image: product ", id)
      products_with_no_image_count += 1
      products_with_no_image.append(id)
      gcs_image_url.append(None)

  #appending gcs image uri into dataframe
  gcs_image_loc = pd.DataFrame(gcs_image_url)
  gcs_image_loc.columns = ["image_uri"]

  df_with_gcs_image_uri = pd.concat([df, gcs_image_loc], axis=0)
  df_with_gcs_image_uri = df_with_gcs_image_uri.drop('image', axis=1)

  return df_with_gcs_image_uri

# %%
df_with_gcs_image_uri = get_product_image(df_with_cat)

# %%
df_with_gcs_image_uri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uniq_id                 20000 non-null  object
#  1   product_name            20000 non-null  object
#  2   description             20000 non-null  object
#  3   brand                   14136 non-null  object
#  4   image                   19997 non-null  object
#  5   product_specifications  19986 non-null  object
#  6   c0_name                 20000 non-null  object
#  7   c1_name                 19672 non-null  object
#  8   c2_name                 18543 non-null  object
#  9   c3_name                 14124 non-null  object
#  10  attributes              19986 non-null  object
#  11  image_uri               18360 non-null  object
# dtypes: object(12)
# memory usage: 2.0+ MB

# %%
#Filtering null values
non_null_image_df = df_with_gcs_image_uri[df_with_gcs_image_uri['image_uri'].notnull()]
non_null_image_df = non_null_image_df[non_null_image_df['description'].notnull()]

# %%
non_null_image_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18360 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uniq_id                 18360 non-null  object
#  1   product_name            18360 non-null  object
#  2   description             18360 non-null  object
#  3   brand                   13476 non-null  object
#  4   image                   18360 non-null  object
#  5   product_specifications  18347 non-null  object
#  6   c0_name                 18360 non-null  object
#  7   c1_name                 18064 non-null  object
#  8   c2_name                 16940 non-null  object
#  9   c3_name                 12829 non-null  object
#  10  attributes              18347 non-null  object
#  11  image_uri               18360 non-null  object
# dtypes: object(12)
# memory usage: 1.8+ MB

# %%
#Dropping redundant columns
non_null_image_df = non_null_image_df.drop(['image','product_specifications'], axis=1)
non_null_image_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18360 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uniq_id       18360 non-null  object
#  1   product_name  18360 non-null  object
#  2   description   18360 non-null  object
#  3   brand         13476 non-null  object
#  4   c0_name       18360 non-null  object
#  5   c1_name       18064 non-null  object
#  6   c2_name       16940 non-null  object
#  7   c3_name       12829 non-null  object
#  8   attributes    18347 non-null  object
#  9   image_uri     18360 non-null  object
# dtypes: object(10)
# memory usage: 1.5+ MB

# %%
non_null_image_df.to_csv('flipkart_preprocessed.csv', header=False, index=False)

# %%
#Copying the cleaned dataset into gcs
# !gsutil cp flipkart_preprocessed.csv gs://genai-product-catalog/
# Out:
# Copying file://flipkart_preprocessed.csv [Content-Type=text/csv]...
# - [1 files][ 14.0 MiB/ 14.0 MiB]
# Operation completed over 1 objects/14.0 MiB.

# %%
non_null_image_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18449 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uniq_id       18449 non-null  object
#  1   product_name  18449 non-null  object
#  2   description   18449 non-null  object
#  3   c0_name       18449 non-null  object
#  4   c1_name       18152 non-null  object
#  5   c2_name       17023 non-null  object
#  6   c3_name       12908 non-null  object
#  7   image_uri     18449 non-null  object
# dtypes: object(8)
# memory usage: 1.3+ MB

# %%
non_null_image_df.head()
# Out:
#                             uniq_id  \
# 0  c2d766ca982eca8304150849735ffef9
# 1  7f7036a6d550aaa89d34c77bd39a5e48
# 2  f449ec65dcbc041b6ae5e6a32717d01b
# 3  0973b37acd0c664e3de26e97e5571454
# 5  c2a17313954882c1dba461863e98adf2
#
#                                         product_name  \
# 0                Alisha Solid Women's Cycling Shorts
# 1                FabHomeDecor Fabric Double Sofa Bed
# 2                                         AW Bellies
# 3                Alisha Solid Women's Cycling Shorts
# 5  Eternal Gandhi Super Series Crystal Paper Weig...
#
#                                          description           brand  \
# 0  key feature alisha solid woman cycling short c...          Alisha
# 1  fabhomedecor fabric double sofa bed finish col...    FabHomeDecor
# 2  key feature aw belly sandal wedge heel casual ...              AW
# 3  key feature alisha solid woman cycling short c...          Alisha
# 5  key feature eternal gandhi super series crysta...  Eternal Gandhi
#
#                                              c0_name                c1_name  \
# 0                                           Clothing       Women's Clothing
# 1                                          Furniture  Living Room Furniture
# 2                                           Footwear       Women's Footwear
# 3                                           Clothing       Women's Clothing
# 5  Eternal Gandhi Super Series Crystal Paper Weig...                   None
#
#                       c2_name  \
# 0  Lingerie, Sleep & Swimwear
# 1          Sofa Beds & Futons
# 2                  Ballerinas
# 3  Lingerie, Sleep & Swimwear
# 5                        None
#
#                                              c3_name  \
# 0                                             Shorts
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                                         AW Bellies
# 3                                             Shorts
# 5                                               None
#
#                                           attributes  \
# 0  {"Number of Contents in Sales Package": "Pack ...
# 1  {"Installation & Demo Details": "Installation ...
# 2  {"Ideal For": "Women", "Occasion": "Casual", "...
# 3  {"Number of Contents in Sales Package": "Pack ...
# 5  {"Model Name": "Gandhi Paper Weight Mark V", "...
#
#                                            image_uri
# 0  gs://genai-product-catalog/flipkart_20k_oct26/...
# 1  gs://genai-product-catalog/flipkart_20k_oct26/...
# 2  gs://genai-product-catalog/flipkart_20k_oct26/...
# 3  gs://genai-product-catalog/flipkart_20k_oct26/...
# 5  gs://genai-product-catalog/flipkart_20k_oct26/...

# %%
#Checking for categories/sub-categories repetition
non_null_image_df.reset_index(drop=True, inplace=True)
col1 = non_null_image_df['c0_name']
col2 = non_null_image_df['c1_name']
col3 = non_null_image_df['c2_name']
col4 = non_null_image_df['c3_name']

# %%
'''
Categoty Tree [depth 4]:
root -> child -> sub-child -> leaf
'''

duplicate_index = []
for i in range(0,len(col1)):
    if (col1[i] == col2[i] and col1[i] and col2[i]):
      print('category repeating: root & child is same')
      print(i)
      print(col1[i],col2[i], col3[i], col4[i])
    if (col2[i] == col3[i] and col2[i] and col3[i]):
      print('category repeating: child & sub-child is same')
      print(i)
      print(col1[i],col2[i], col3[i], col4[i])
    if (col3[i] == col4[i] and col3[i] and col4[i]):
      print('category repeating:  sub-child & leaf is same')
      print(i)
      print(col1[i],"'",col2[i], ",", col3[i], ",", col4[i])
    if (col1[i] == col3[i] and col1[i] and col3[i]):
      print('category repeating: root & sub-child is same')
      print(i)
    if (col1[i] == col4[i] and col1[i] and col4[i]):
      print('category repeating: root & leaf is same')
      print(i)
    if (col2[i] == col4[i] and col2[i] and col4[i]):
      print('category repeating: child & leaf is same')
      print(i)
# Out:
# category repeating:  sub-child & leaf is same
# 1533
# Automotive ' Accessories & Spare parts , Tyres , Tyres
# category repeating:  sub-child & leaf is same
# 9220
# Clothing ' Women's Clothing , Leggings & Jeggings , Leggings & Jeggings
# category repeating:  sub-child & leaf is same
# 10332
# Clothing ' Women's Clothing , Leggings & Jeggings , Leggings & Jeggings
# category repeating:  sub-child & leaf is same
# 10343
# Clothing ' Women's Clothing , Leggings & Jeggings , Leggings & Jeggings
# category repeating:  sub-child & leaf is same
# 13868
# Clothing ' Women's Clothing , Leggings & Jeggings , Leggings & Jeggings
# category repeating:  sub-child & leaf is same
# 13981
# Clothing ' Women's Clothing , Leggings & Jeggings , Leggings & Jeggings
# category repeating:  sub-child & leaf is same
# 13982
# Clothing ' Women's Clothing , Leggings & Jeggings , Leggings & Jeggings
# category repeating:  sub-child & leaf is same
# 14007
# Clothing ' Women's Clothing , Leggings & Jeggings , Leggings & Jeggings
# category repeating:  sub-child & leaf is same
# 14373
# Clothing ' Women's Clothing , Leggings & Jeggings , Leggings & Jeggings
# category repeating:  sub-child & leaf is same
# 16386
# Beauty and Personal Care ' Health Care , Health Care Accessories , Health Care Accessories
# category repeating:  sub-child & leaf is same
# 17517
# Clothing ' Women's Clothing , Leggings & Jeggings , Leggings & Jeggings

# %% [markdown]
# **Some of the sub-child & leaf are matching. We should remove the duplicate category**

# %% [markdown]
# *Please check the index from above result and update below list accordingly, before running this cell*
#
# *This approach is to make leaf categories as Null*

# %%
#please check the index and update below list, before running this cell
#duplicate_index = [1533,9220, 10332, 10343,13868,13981,13982,14007,14373,16386,17517]
for i in duplicate_index:
  non_null_image_df['c3_name'][i] = None

# %% [markdown]
# **Checking brand name in the category**

# %%
non_null_image_df[non_null_image_df['brand'].isin(non_null_image_df['c0_name'])]
# Out:
# Empty DataFrame
# Columns: [uniq_id, product_name, description, brand, c0_name, c1_name, c2_name, c3_name, attributes, image_uri]
# Index: []

# %%
non_null_image_df[non_null_image_df['brand'].isin(non_null_image_df['c1_name'])]
# Out:
#                                 uniq_id            product_name  \
# 17024  1bcf75f2f9cae1f0de161a3c1ff39f88  Frames MDF Photo Frame
#
#                                              description   brand  \
# 17024  key feature frame mdf photo wall table decor f...  Frames
#
#                           c0_name              c1_name            c2_name  \
# 17024  Home Decor & Festive Needs  Wall Decor & Clocks  Wall Photo Frames
#
#                         c3_name  \
# 17024  Frames Wall Photo Frames
#
#                                               attributes  \
# 17024  {"Frame Material": "MDF", "Backing": "Wood", "...
#
#                                                image_uri
# 17024  gs://genai-product-catalog/flipkart_20k_oct26/...

# %%
non_null_image_df[non_null_image_df['brand'].isin(non_null_image_df['c2_name'])]
# Out:
#                                uniq_id  \
# 9687  8a3e23b6dc2d811d53bf9544c3e5f1a5
#
#                                   product_name  \
# 9687  Tennis Tennis Sports Shoes Running Shoes
#
#                                             description   brand   c0_name  \
# 9687  key feature tennis sport shoe run material eva...  Tennis  Footwear
#
#              c1_name       c2_name              c3_name  \
# 9687  Men's Footwear  Sports Shoes  Tennis Sports Shoes
#
#                                              attributes  \
# 9687  {"Ideal For": "Men", "Occasion": "Sports", "So...
#
#                                               image_uri
# 9687  gs://genai-product-catalog/flipkart_20k_oct26/...

# %%
non_null_image_df[non_null_image_df['brand'].isin(non_null_image_df['c3_name'])]
# Out:
# Empty DataFrame
# Columns: [uniq_id, product_name, description, brand, c0_name, c1_name, c2_name, c3_name, attributes, image_uri]
# Index: []

# %%
non_null_image_df.info()
# %%
#non_null_image_df.to_csv('18K_no_duplicate.csv', header=False, index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18360 entries, 0 to 18359
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uniq_id       18360 non-null  object
#  1   product_name  18360 non-null  object
#  2   description   18360 non-null  object
#  3   brand         13476 non-null  object
#  4   c0_name       18360 non-null  object
#  5   c1_name       18064 non-null  object
#  6   c2_name       16940 non-null  object
#  7   c3_name       12818 non-null  object
#  8   attributes    18347 non-null  object
#  9   image_uri     18360 non-null  object
# dtypes: object(10)
# memory usage: 1.4+ MB

# %%
# !gsutil cp 18K_no_duplicate.csv gs://genai-product-catalog/
# Out:
# Copying file://18K_no_duplicate.csv [Content-Type=text/csv]...
# -
# Operation completed over 1 objects/14.0 MiB.

# %%
columns = non_null_image_df.columns
with pd.ExcelWriter('flipkart_category_analysis.xlsx') as writer:
  for col in columns:
    non_null_image_df[col].value_counts().to_excel(writer, sheet_name=col)

# %% [markdown]
# # Preparing for Generating Embedding

# %%
#renaming column name to match embedding generation code
non_null_image_df.rename(columns={'uniq_id':'id'}, inplace=True)

# %% [markdown]
# ### Upload preprocessed data into BigQuery

# %%
from google.cloud import bigquery

def create_table(client, table_id, schema):
    table = bigquery.Table(table_id, schema=schema)
    table = client.create_table(table,exists_ok=True)  # Make an API request
    print(
        "Created table {}.{}.{}".format(table.project, table.dataset_id, table.table_id)
    )
def upload_df_into_bq(client, table_id, df):
    #df.to_gbq(table_id, PROJECT, if_exists='replace', progress_bar=True)
    job_config = bigquery.LoadJobConfig(schema=schema)
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    #job_config.skip_leading_rows = 1
    job_config.autodetect = False
    job_config.source_format = 'CSV'
    job = client.load_table_from_dataframe(df, table_id, job_config=job_config)
    job.result()
    print(
        "Uploaded dataframe into table {}.{}".format(PROJECT, table_id)
    )

# %%
PROJECT = 'solutions-2023-mar-107'
LOCATION = 'us-central1'
table_id = 'solutions-2023-mar-107.flipkart.preprocessed_data'

schema = [
    bigquery.SchemaField('id', 'STRING', mode='REQUIRED'),
    bigquery.SchemaField('product_name', 'STRING', mode='REQUIRED'),
    bigquery.SchemaField('description', 'STRING', mode='REQUIRED'),
    bigquery.SchemaField('brand', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('c0_name', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('c1_name', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('c2_name', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('c3_name', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('attributes', 'JSON', mode='NULLABLE'),
    bigquery.SchemaField('image_uri', 'STRING', mode='REQUIRED')
]
client = bigquery.Client(PROJECT)

create_table(client, table_id, schema)

upload_df_into_bq(client, table_id, non_null_image_df)

# %% [markdown]
# **Adding new (empty) columns for text & image embeddings**

# %%
table = client.get_table(table_id)
original_schema = table.schema
new_schema = original_schema[:]  # Creates a copy of the schema.
new_schema.append(bigquery.SchemaField('text_embedding', 'FLOAT', mode='REPEATED'))
new_schema.append(bigquery.SchemaField('image_embedding', 'FLOAT', mode='REPEATED'))

table.schema = new_schema
table = client.update_table(table, ["schema"])  # Make an API request.

if len(table.schema) == len(original_schema) + 2 == len(new_schema):
    print("Two new columns have been added.")
else:
    print("Something went wrong.")
# Out:
# Two new columns have been added.
