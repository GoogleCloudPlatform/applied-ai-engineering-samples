# %%
# @title Install Necessary Packages

first = False
if first:
  ! pip install google-cloud-aiplatform --upgrade --quiet
  ! pip install shapely==1.8.5 --quiet
  ! pip install sqlalchemy --upgrade --quiet
  ! pip install asyncio asyncpg cloud-sql-python-connector["asyncpg"] --quiet
  ! pip install numpy pandas --quiet
  ! pip install pgvector --quiet
  ! pip install pg8000 --quiet
  ! pip install gradio --quiet

# %%
# get_ipython().kernel.do_shutdown(True)

# %%
from google.colab import auth
auth.authenticate_user()

# %%
import os
auth_user=!gcloud config get-value account
auth_user=auth_user[0]
print('Authenticated User: ' + str(auth_user))
# Out:
# Authenticated User: moksh.google@shoppersstop.com

# %%
#@title Assignment of Variables
source_type='BigQuery'


# @markdown Provide the below details to start using the notebook
PROJECT_ID='ss-genai-npd-svc-prj-01' # @param {type:"string"}
LLM_ENDPOINT_REGION = 'asia-southeast1' # @param {type:"string"}
DATAPROJECT_ID='ss-genai-npd-svc-prj-01'  # This needs to be adjusted when using the bq public dataset

#set and show gcp project
# !gcloud config set project {PROJECT_ID}
# !gcloud config get-value project
#!bash gcloud auth application-default login


# BQ Schema (DATASET) where tables leave

schema="NA" # @param {type:"string"}.  ### DDL extraction performed at this level, for the entire schema
USER_DATASET= DATAPROJECT_ID + '.' + schema

table_id_list="ss-jarvis-npd-svc-prj-01.Customer.FC_Customer_Master, ss-jarvis-npd-svc-prj-01.Customer.Persona,ss-jarvis-npd-svc-prj-01.Product.Product_Master, ss-jarvis-npd-svc-prj-01.Sales.storesales,ss-jarvis-npd-svc-prj-01.Sales.ecommdenormdata,ss-jarvis-npd-svc-prj-01.Store.dim_location_full" # @param {type:"string"}


# BQ Schema (DATASET) where tables leave

# Execution Parameters
SQL_VALIDATION='ALL'
INJECT_ONE_ERROR=False
EXECUTE_FINAL_SQL=True
SQL_MAX_FIX_RETRY=3
AUTO_ADD_KNOWNGOOD_SQL=True

# Analytics Warehouse
ENABLE_ANALYTICS=True
DATASET_NAME='nl2sql'
DATASET_LOCATION='asia-south1'
LOG_TABLE_NAME='query_logs'
FULL_LOG_TEXT=''


# Palm Models to use
model_id='gemini-pro' # @param {type:"string"}
chat_model_id='codechat-bison-32k' # @param {type:"string"}
embeddings_model='textembedding-gecko@001'
# Out:
# Updated property [core/project].
# ss-genai-npd-svc-prj-01

# %%
# @title Common Imports
import time
import datetime
from datetime import datetime, timezone
import hashlib
import vertexai
import pandas
import pandas_gbq
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from sqlalchemy import text
import pandas as pd
from google.colab import data_table
data_table.enable_dataframe_formatter()
import json
from google.cloud import bigquery
from google.cloud.exceptions import NotFound
from logging import exception
import asyncio
import asyncpg
from google.cloud.sql.connector import Connector
import numpy as np
from pgvector.asyncpg import register_vector
from google.cloud import aiplatform
from vertexai.language_models import TextEmbeddingModel
import gradio as gr

# %%
# @title Model Endpoint Creation
def createModel(PROJECT_ID, LLM_ENDPOINT_REGION, model_id):
  from vertexai.preview.language_models import TextGenerationModel
  from vertexai.preview.language_models import CodeGenerationModel
  from vertexai.preview.language_models import CodeChatModel
  from vertexai.preview.generative_models import GenerativeModel

  if model_id == 'code-bison-32k':
    model = CodeGenerationModel.from_pretrained('code-bison-32k')
  elif model_id == 'text-bison-32k':
    model = TextGenerationModel.from_pretrained('text-bison-32k')
  elif model_id == 'codechat-bison-32k':
    model = CodeChatModel.from_pretrained("codechat-bison-32k")
  elif model_id == 'gemini-pro':
    model = GenerativeModel("gemini-pro")
  else:
    raise ValueError
  return model


vertexai.init(project=PROJECT_ID, location=LLM_ENDPOINT_REGION)
model=createModel(PROJECT_ID, LLM_ENDPOINT_REGION,model_id)
chat_model=createModel(PROJECT_ID, LLM_ENDPOINT_REGION,chat_model_id)

# %%
# @title Functions to pull metadata from BQ (Tables, Columns, PKs and FKs)
def create_metadata_sqls(table_id_list):
  get_columns_sql="""SELECT
    TABLE_CATALOG as project_id, TABLE_SCHEMA as owner , TABLE_NAME as table_name, COLUMN_NAME as column_name,
    DATA_TYPE as data_type, ROUNDING_MODE as rounding_mode, description
  FROM
    {}.INFORMATION_SCHEMA.COLUMN_FIELD_PATHS WHERE TABLE_NAME IN {}
  ORDER BY
   project_id, owner, table_name, column_name """

  get_fkeys_sql="""SELECT T.CONSTRAINT_CATALOG, T.CONSTRAINT_SCHEMA, T.CONSTRAINT_NAME,
T.TABLE_CATALOG as project_id, T.TABLE_SCHEMA as owner, T.TABLE_NAME as table_name, T.CONSTRAINT_TYPE,
T.IS_DEFERRABLE, T.ENFORCED, K.COLUMN_NAME
FROM
{}.INFORMATION_SCHEMA.TABLE_CONSTRAINTS T
JOIN {}.INFORMATION_SCHEMA.KEY_COLUMN_USAGE K
ON K.CONSTRAINT_NAME=T.CONSTRAINT_NAME
WHERE T.TABLE_NAME IN {} AND
T.CONSTRAINT_TYPE="FOREIGN KEY"
ORDER BY
project_id, owner, table_name"""

  get_pkeys_sql="""
SELECT T.CONSTRAINT_CATALOG, T.CONSTRAINT_SCHEMA, T.CONSTRAINT_NAME,
T.TABLE_CATALOG as project_id, T.TABLE_SCHEMA as owner, T.TABLE_NAME as table_name, T.CONSTRAINT_TYPE,
T.IS_DEFERRABLE, T.ENFORCED, K.COLUMN_NAME
FROM
{}.INFORMATION_SCHEMA.TABLE_CONSTRAINTS T
JOIN {}.INFORMATION_SCHEMA.KEY_COLUMN_USAGE K
ON K.CONSTRAINT_NAME=T.CONSTRAINT_NAME
WHERE  T.TABLE_NAME IN {} AND
T.CONSTRAINT_TYPE="PRIMARY KEY"
ORDER BY
project_id, owner, table_name
"""


  get_table_comments_sql="""
select TABLE_CATALOG as project_id, TABLE_SCHEMA as owner , TABLE_NAME as table_name, OPTION_NAME, OPTION_TYPE, OPTION_VALUE as comments
FROM
{}.INFORMATION_SCHEMA.TABLE_OPTIONS
WHERE TABLE_NAME IN {} AND
 OPTION_NAME = "description"
ORDER BY
project_id, owner, table_name
"""
  table_id_list=table_id_list.split(",")
  result = []
  for table_id in table_id_list:
    # print(table_id)
    project, schema, table_name = table_id.split('.')
    project = project.strip()
    schema = schema.strip()
    table_name = table_name.strip()
    result.append({'project': project, 'schema': schema, 'table_name': table_name})
  result.sort(key=lambda x: x['project'])
  # print((result))
  project_schema_groups = {}
  for item in result:
      key = (item['project'], item['schema'])
      project_schema_groups.setdefault(key, []).append(item['table_name'])

  sql_statements_1, sql_statements_2, sql_statements_3, sql_statements_4 = [], [], [], []
  for (project, schema), table_names in project_schema_groups.items():
      table_names_placeholder = "({})".format(", ".join("'{}'".format(t) for t in table_names))
      sql_1 = get_columns_sql.format('{}.{}'.format(project, schema), table_names_placeholder)
      sql_2 = get_fkeys_sql.format('{}.{}'.format(project, schema), '{}.{}'.format(project, schema), table_names_placeholder)
      sql_3 = get_pkeys_sql.format('{}.{}'.format(project, schema), '{}.{}'.format(project, schema), table_names_placeholder)
      sql_4 = get_table_comments_sql.format('{}.{}'.format(project, schema), table_names_placeholder)
      sql_statements_1.append(f"({sql_1})")
      sql_statements_2.append(f"({sql_2})")
      sql_statements_3.append(f"({sql_3})")
      sql_statements_4.append(f"({sql_4})")

  get_columns_sql = " UNION ALL ".join(sql_statements_1) + ";"
  get_fkeys_sql = " UNION ALL ".join(sql_statements_2) + ";"
  get_pkeys_sql = " UNION ALL ".join(sql_statements_3) + ";"
  get_table_comments_sql = " UNION ALL ".join(sql_statements_4) + ";"

  return get_columns_sql, get_fkeys_sql, get_pkeys_sql, get_table_comments_sql

# %% [markdown]
# #Utility Functions

# %%
def schema_generator(sql):
  df = pandas_gbq.read_gbq(sql, project_id=PROJECT_ID)
  return df


def add_table_comments(columns_df, pkeys_df, fkeys_df, table_comments_df):

  for index, row in table_comments_df.iterrows():
    if row['comments'] is None: ## or row['comments'] is not None:
        q=f"table_name == '{row['table_name']}' and owner == '{row['owner']}'"
        context_prompt = f"""
        Generate detailed table comments for the table {row['project_id']}.{row['owner']}.{row['table_name']}
Remember that these comments should help LLMs to help build better SQL for any quries related to this table.
        Parameters:
        - column metadata: {columns_df.query(q).to_markdown(index = False)}
        - primary key metadata: {pkeys_df.query(q).to_markdown(index = False)}
        - foreign keys metadata: {fkeys_df.query(q).to_markdown(index = False)}
        - table metadata: {table_comments_df.query(q).to_markdown(index = False)}
      """
        #context_query = model.predict(context_prompt, max_output_tokens = 256, temperature= 0.2)
        # print(context_prompt)
        context_query = model.generate_content(context_prompt, stream=False)
        # print(clean_sql(str(context_query.candidates[0])))
        table_comments_df.at[index, 'comments'] = clean_sql(str(context_query.candidates[0].text))

  return table_comments_df



def add_column_comments(columns_df, pkeys_df, fkeys_df, table_comments_df):
  for index, row in columns_df.iterrows():
    if row['description'] == None:
      q=f"table_name == '{row['table_name']}' and owner == '{row['owner']}'"
      context_prompt = f"""
      Generate comments for the column {row['project_id']}.{row['owner']}.{row['table_name']}.{row['column_name']}

      Remember that these comments should help LLMs to help generate better SQL for any queries related to these columns.

      Consider the below information to generate a good comment

      Description of the column is : {row['description']}
      Data type of the column is : {row['data_type']}
      Details of the table of this column are below:
      {table_comments_df.query(q).to_markdown(index=False)}
      Details of the primary keys of the table containing this column are below:
      {pkeys_df.query(q).to_markdown(index=False)}
      Details of the foreign keys of the table containing this column are below:
      {fkeys_df.query(q).to_markdown(index=False)}
      """
      # print(context_prompt)
      context_query = model.generate_content(context_prompt, stream=False)
      print({row['column_name']})
      columns_df.at[index, 'column_comments'] = clean_sql(str(context_query.candidates[0].text))
  return columns_df

def get_column_sample(columns_df):
  sample_column_list=[]

  for index, row in columns_df.iterrows():
    get_column_sample_sql=f'''
        SELECT STRING_AGG(CAST(value AS STRING)) as sample_values
        FROM UNNEST((SELECT APPROX_TOP_COUNT({row["column_name"]}, 5) as osn
                     FROM `{row["project_id"]}.{row["owner"]}.{row["table_name"]}`
                ))
    '''
    column_samples_df=schema_generator(get_column_sample_sql)
    sample_column_list.append(column_samples_df['sample_values'].to_string(index=False))

  columns_df["sample_values"]=sample_column_list
  return columns_df



def clean_sql(result):
  result = result.replace("```sql", "").replace("```", "")
  return result

# %%
# Augment Table dataframe with detailed description. This detailed description column will be the one used as the document when adding the record to the VectorDB
def build_table_desc(table_comments_df,columns_df,pkeys_df,fkeys_df):
  aug_table_comments_df = table_comments_df

  #print(len(aug_table_comments_df))
  #print(len(table_comments_df))

  cur_table_name = ""
  cur_table_owner = ""
  cur_project_id = ""
  cur_full_table= cur_project_id + '.' + cur_table_owner + '.' + cur_table_name

  for index_aug, row_aug in aug_table_comments_df.iterrows():

    cur_table_name = str(row_aug['table_name'])
    cur_table_owner = str(row_aug['owner'])
    cur_project_id = str(row_aug['project_id'])
    cur_full_table= cur_project_id + '.' + cur_table_owner + '.' + cur_table_name
    #print('\n' + cur_table_owner + '.' + cur_table_name + ':')

    table_cols=[]
    table_cols_datatype=[]
    table_col_comments=[]
    table_pk_cols=[]
    table_fk_cols=[]

    for index, row in columns_df.loc[ (columns_df['owner'] == cur_table_owner) & (columns_df['table_name'] == cur_table_name) ].iterrows():
      # Inside each owner.table_name combination
      table_cols.append( row['column_name']  )
      table_cols_datatype.append( row['column_name'] + ' (' + row['data_type'] + ') '  )
      col_comments_text=f"""
        Column {row['column_name']} belongs to table {row['table_name']}, owner {row['owner']}.
        It has data type {row['data_type']}.
        Sample values are {row['sample_values']}.
        Description of the column is {row['description']}.
        User commments: {row['column_comments']}.
      """
      table_col_comments.append(col_comments_text)

    for index, row in pkeys_df.loc[ (pkeys_df['owner'] == cur_table_owner) & (pkeys_df['table_name'] == cur_table_name)  ].iterrows():
      # Inside each owner.table_name combination
      table_pk_cols.append( row['column_name']  )

    for index, row in fkeys_df.loc[ (fkeys_df['owner'] == cur_table_owner) & (fkeys_df['table_name'] == cur_table_name) ].iterrows():
      # Inside each owner.table_name combination
      fk_cols_text=f"""
      Column {row['column_name']} is equal to column {row['r_column_name']} in table {row['owner']}.{row['r_table_name']}
      """
      table_fk_cols.append(fk_cols_text)


    if len(",".join(table_pk_cols)) == 0:
      final_pk_cols = "None"
    else:
      final_pk_cols = ",".join(table_pk_cols)

    if len(",".join(table_fk_cols)) == 0:
      final_fk_cols = "None"
    else:
      final_fk_cols = ",".join(table_fk_cols)

    aug_table_desc=f"""
      Table Name: {cur_full_table} |
      Owner: {cur_table_owner} |
      Schema Columns:{",".join(table_cols)} |
      Column Types: {",".join(table_cols_datatype)} |
      Primary Key: {final_pk_cols} |
      Foreign Keys: {final_fk_cols} |
      Project_id: {str(row_aug['project_id'])} |
      Table Comments: {str(row_aug['comments'])}
    """

    #print ('Current aug dataset row: '  + str(row_aug['table_name']))
    #print(aug_table_desc)

    # Works well
    aug_table_comments_df.at[index_aug, 'detailed_description'] = aug_table_desc
  return aug_table_comments_df

# %%
# Augment columns dataframe with detailed description. This detailed description column will be the one used as the document when adding the record to the VectorDB

def build_column_desc(columns_df):
  aug_columns_df = columns_df

  print(len(aug_columns_df))
  #print(len(columns_df))

  cur_table_name = ""
  cur_table_owner = ""
  cur_full_table= cur_table_owner + '.' + cur_table_name

  for index_aug, row_aug in aug_columns_df.iterrows():

    cur_table_name = str(row_aug['table_name'])
    cur_table_owner = str(row_aug['owner'])
    cur_full_table= cur_table_owner + '.' + cur_table_name
    curr_col_name = str(row_aug['column_name'])
    curr_col_desc = str(row_aug['description'])

    print('\n' + cur_table_owner + '.' + cur_table_name + ':')

    col_comments_text=f"""
        Column Name: {row_aug['column_name']} |
        Sample values: {row_aug['sample_values']} |
        Data type: {row_aug['data_type']} |
        Table Name: {row_aug['table_name']} |
        Table Owner: {row_aug['owner']} |
        Project_id: {row_aug['project_id']}
        Column description: {row_aug['description']}
    """
        #Low value: {row_aug['low_value']} |
        #High value: {row_aug['high_value']} |
        #User commments: {row_aug['column_comments']}

    print(' Column ' + cur_full_table + '.' + curr_col_name + " Description: " + col_comments_text)

    aug_columns_df.at[index_aug, 'detailed_description'] = col_comments_text
  return aug_columns_df

# %% [markdown]
# # Vector Pre-Processing

# %%
# print(table_id_list)
get_columns_sql, get_fkeys_sql, get_pkeys_sql, get_table_comments_sql=create_metadata_sqls(table_id_list)

# print(get_columns_sql)
# print(get_fkeys_sql)
# print(get_pkeys_sql)
# print(get_table_comments_sql)

# %%
columns_df=schema_generator(get_columns_sql)
fkeys_df=schema_generator(get_fkeys_sql)
pkeys_df=schema_generator(get_pkeys_sql)
table_comments_df=schema_generator(get_table_comments_sql)
# Out:
# Downloading: 100%|██████████|
# Downloading: |          |
# Downloading: |          |
# Downloading: 100%|██████████|

# %%
# data_table.DataTable(fkeys_df)
# data_table.DataTable(pkeys_df)
# data_table.DataTable(columns_df)
data_table.DataTable(table_comments_df)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>project_id</th>
#       <th>owner</th>
#       <th>table_name</th>
#       <th>OPTION_NAME</th>
#       <th>OPTION_TYPE</th>
#       <th>comments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Store</td>
#       <td>dim_location_full</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Store demographic details"</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Sales</td>
#       <td>storesales</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains transaction level sales data from st...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Sales</td>
#       <td>ecommdenormdata</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains Transaction level E-Commerce Sales d...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Product</td>
#       <td>Product_Master</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains SKU level details about products"</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>FC_Customer_Master</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains Analytical info about the members. T...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>Persona</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains Detailed Info about personas about e...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# columns_df=get_column_sample(columns_df)
# data_table.DataTable(columns_df)
columns_df["sample_values"]=None

# %%
# Using Gemini to add table comments if comments are null
table_comments_df=add_table_comments(columns_df, pkeys_df, fkeys_df, table_comments_df)
data_table.DataTable(table_comments_df)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>project_id</th>
#       <th>owner</th>
#       <th>table_name</th>
#       <th>OPTION_NAME</th>
#       <th>OPTION_TYPE</th>
#       <th>comments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Store</td>
#       <td>dim_location_full</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Store demographic details"</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Sales</td>
#       <td>storesales</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains transaction level sales data from st...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Sales</td>
#       <td>ecommdenormdata</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains Transaction level E-Commerce Sales d...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Product</td>
#       <td>Product_Master</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains SKU level details about products"</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>FC_Customer_Master</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains Analytical info about the members. T...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>Persona</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains Detailed Info about personas about e...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# columns_df=add_column_comments(columns_df, pkeys_df, fkeys_df, table_comments_df)
columns_df["column_comments"]=None
data_table.DataTable(columns_df)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>project_id</th>
#       <th>owner</th>
#       <th>table_name</th>
#       <th>column_name</th>
#       <th>data_type</th>
#       <th>rounding_mode</th>
#       <th>description</th>
#       <th>sample_values</th>
#       <th>column_comments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Store</td>
#       <td>dim_location_full</td>
#       <td>town</td>
#       <td>STRING</td>
#       <td>None</td>
#       <td>The name of the town where the store is located</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Store</td>
#       <td>dim_location_full</td>
#       <td>state</td>
#       <td>STRING</td>
#       <td>None</td>
#       <td>The state where the town is situated</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Store</td>
#       <td>dim_location_full</td>
#       <td>zone</td>
#       <td>STRING</td>
#       <td>None</td>
#       <td>The geographical zone classification where the...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Store</td>
#       <td>dim_location_full</td>
#       <td>zplant</td>
#       <td>STRING</td>
#       <td>None</td>
#       <td>he identification code for the store</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Store</td>
#       <td>dim_location_full</td>
#       <td>citytier</td>
#       <td>STRING</td>
#       <td>None</td>
#       <td>The tier classification of the city (e.g., Met...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>571</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>Persona</td>
#       <td>airport_store_sales</td>
#       <td>BIGNUMERIC(48, 10)</td>
#       <td>None</td>
#       <td>Total sales in airport stores</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>572</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>Persona</td>
#       <td>discount_slab</td>
#       <td>STRING</td>
#       <td>None</td>
#       <td>Slab/category based on discount percentage</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>573</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>Persona</td>
#       <td>ps_contri_slab</td>
#       <td>STRING</td>
#       <td>None</td>
#       <td>Slab/category based on private sales contribution</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>574</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>Persona</td>
#       <td>storename</td>
#       <td>STRING</td>
#       <td>None</td>
#       <td>Name of the store where the customer made purc...</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>575</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>Persona</td>
#       <td>zone</td>
#       <td>STRING</td>
#       <td>None</td>
#       <td>Zone where the store is located</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# <p>576 rows × 9 columns</p>
# </div>

# %%
table_comments_df=build_table_desc(table_comments_df,columns_df,pkeys_df,fkeys_df)

# %%
data_table.DataTable(table_comments_df)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>project_id</th>
#       <th>owner</th>
#       <th>table_name</th>
#       <th>OPTION_NAME</th>
#       <th>OPTION_TYPE</th>
#       <th>comments</th>
#       <th>detailed_description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Store</td>
#       <td>dim_location_full</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Store demographic details"</td>
#       <td>\n      Table Name: ss-jarvis-npd-svc-prj-01.S...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Sales</td>
#       <td>storesales</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains transaction level sales data from st...</td>
#       <td>\n      Table Name: ss-jarvis-npd-svc-prj-01.S...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Sales</td>
#       <td>ecommdenormdata</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains Transaction level E-Commerce Sales d...</td>
#       <td>\n      Table Name: ss-jarvis-npd-svc-prj-01.S...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Product</td>
#       <td>Product_Master</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains SKU level details about products"</td>
#       <td>\n      Table Name: ss-jarvis-npd-svc-prj-01.P...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>FC_Customer_Master</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains Analytical info about the members. T...</td>
#       <td>\n      Table Name: ss-jarvis-npd-svc-prj-01.C...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ss-jarvis-npd-svc-prj-01</td>
#       <td>Customer</td>
#       <td>Persona</td>
#       <td>description</td>
#       <td>STRING</td>
#       <td>"Contains Detailed Info about personas about e...</td>
#       <td>\n      Table Name: ss-jarvis-npd-svc-prj-01.C...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
columns_df=build_column_desc(columns_df)
# Out:
# Streaming output truncated to the last 5000 lines.
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.ny_mtd1 Description:
#         Column Name: ny_mtd1 |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.nny_mtd1 Description:
#         Column Name: nny_mtd1 |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.emp_id Description:
#         Column Name: emp_id |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.emp_desig_description Description:
#         Column Name: emp_desig_description |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.emp_name Description:
#         Column Name: emp_name |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.l2_code Description:
#         Column Name: l2_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.category_code Description:
#         Column Name: category_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.department_code Description:
#         Column Name: department_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.brand_code Description:
#         Column Name: brand_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.merchandising_category_code Description:
#         Column Name: merchandising_category_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.l7_code Description:
#         Column Name: l7_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.l7 Description:
#         Column Name: l7 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.options_nbr Description:
#         Column Name: options_nbr |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.merchandising_sub_category_code Description:
#         Column Name: merchandising_sub_category_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.merchandising_sub_category Description:
#         Column Name: merchandising_sub_category |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.style_desc Description:
#         Column Name: style_desc |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.size_desc Description:
#         Column Name: size_desc |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.season_code Description:
#         Column Name: season_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.season_desc Description:
#         Column Name: season_desc |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.fcc_type Description:
#         Column Name: fcc_type |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.grade_entry_dt Description:
#         Column Name: grade_entry_dt |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.grade_entry_dt1 Description:
#         Column Name: grade_entry_dt1 |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.storeformat Description:
#         Column Name: storeformat |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.persona_name Description:
#         Column Name: persona_name |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.cashier_id Description:
#         Column Name: cashier_id |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.cashier_name Description:
#         Column Name: cashier_name |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.trn_start_time Description:
#         Column Name: trn_start_time |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.trn_end_time Description:
#         Column Name: trn_end_time |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.diwali Description:
#         Column Name: diwali |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.dusshera Description:
#         Column Name: dusshera |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.festival Description:
#         Column Name: festival |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.eoss1 Description:
#         Column Name: eoss1 |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.eoss2 Description:
#         Column Name: eoss2 |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.black_friday Description:
#         Column Name: black_friday |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.singles_day Description:
#         Column Name: singles_day |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.good_friday Description:
#         Column Name: good_friday |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.republic_day Description:
#         Column Name: republic_day |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.independence_day Description:
#         Column Name: independence_day |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.christmas Description:
#         Column Name: christmas |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.new_year Description:
#         Column Name: new_year |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.mothers_day Description:
#         Column Name: mothers_day |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.fathers_day Description:
#         Column Name: fathers_day |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.valentines_day Description:
#         Column Name: valentines_day |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.womens_day Description:
#         Column Name: womens_day |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.mens_day Description:
#         Column Name: mens_day |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.holi Description:
#         Column Name: holi |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.ramadan Description:
#         Column Name: ramadan |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.ps_repeat_trial_flag Description:
#         Column Name: ps_repeat_trial_flag |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.pos_key Description:
#         Column Name: pos_key |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.first_connect Description:
#         Column Name: first_connect |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.ltl_llly_flag1 Description:
#         Column Name: ltl_llly_flag1 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.p_ltl_llly_flag1 Description:
#         Column Name: p_ltl_llly_flag1 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.store_closed_flag Description:
#         Column Name: store_closed_flag |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.l1_cd Description:
#         Column Name: l1_cd |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.l1_desc Description:
#         Column Name: l1_desc |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.hsn Description:
#         Column Name: hsn |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.ean Description:
#         Column Name: ean |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.creation_dt Description:
#         Column Name: creation_dt |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.color Description:
#         Column Name: color |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.valuation_class Description:
#         Column Name: valuation_class |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.valuation_class_desc Description:
#         Column Name: valuation_class_desc |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.mmrp_flag Description:
#         Column Name: mmrp_flag |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.collection Description:
#         Column Name: collection |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.block_indicator Description:
#         Column Name: block_indicator |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_1 Description:
#         Column Name: characteristic_1 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_2 Description:
#         Column Name: characteristic_2 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_3 Description:
#         Column Name: characteristic_3 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_4 Description:
#         Column Name: characteristic_4 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_5 Description:
#         Column Name: characteristic_5 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_6 Description:
#         Column Name: characteristic_6 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_7 Description:
#         Column Name: characteristic_7 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_8 Description:
#         Column Name: characteristic_8 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_9 Description:
#         Column Name: characteristic_9 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.characteristic_10 Description:
#         Column Name: characteristic_10 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.llly_date Description:
#         Column Name: llly_date |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.nnny_date Description:
#         Column Name: nnny_date |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.nnny_date1 Description:
#         Column Name: nnny_date1 |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.nnny_date11 Description:
#         Column Name: nnny_date11 |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.llly_mtd Description:
#         Column Name: llly_mtd |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.nnny_mtd Description:
#         Column Name: nnny_mtd |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.url Description:
#         Column Name: url |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.first_sales_dt Description:
#         Column Name: first_sales_dt |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.no_of_weeks1 Description:
#         Column Name: no_of_weeks1 |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.vendor_cd Description:
#         Column Name: vendor_cd |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.vendor_grp_name Description:
#         Column Name: vendor_grp_name |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.beauty_desig Description:
#         Column Name: beauty_desig |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.grade_entry_dt_beauty Description:
#         Column Name: grade_entry_dt_beauty |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.beauty_repeat_trial_flag Description:
#         Column Name: beauty_repeat_trial_flag |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.card_tier Description:
#         Column Name: card_tier |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.pin_code Description:
#         Column Name: pin_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.pin_code_area Description:
#         Column Name: pin_code_area |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.enrolled_store_code Description:
#         Column Name: enrolled_store_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.enrolled_store_name Description:
#         Column Name: enrolled_store_name |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.prod_gender Description:
#         Column Name: prod_gender |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.size Description:
#         Column Name: size |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.length Description:
#         Column Name: length |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.fit Description:
#         Column Name: fit |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.neck_type Description:
#         Column Name: neck_type |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.sleeve_type Description:
#         Column Name: sleeve_type |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.frabic_mat Description:
#         Column Name: frabic_mat |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.knit_oven Description:
#         Column Name: knit_oven |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.pattern Description:
#         Column Name: pattern |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.pack_size Description:
#         Column Name: pack_size |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.pleat Description:
#         Column Name: pleat |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.collar Description:
#         Column Name: collar |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.product_type Description:
#         Column Name: product_type |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.tax_amt Description:
#         Column Name: tax_amt |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.sap_brand_cd Description:
#         Column Name: sap_brand_cd |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.sap_brand_name Description:
#         Column Name: sap_brand_name |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.age_slab Description:
#         Column Name: age_slab |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.life_stage Description:
#         Column Name: life_stage |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.ethnicity Description:
#         Column Name: ethnicity |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.bills_slab Description:
#         Column Name: bills_slab |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.sku_slabs Description:
#         Column Name: sku_slabs |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.beauty_rfm_classification_member Description:
#         Column Name: beauty_rfm_classification_member |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.home_persona Description:
#         Column Name: home_persona |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.cat_tri_repeat Description:
#         Column Name: cat_tri_repeat |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.cat_brand_tri_repeat Description:
#         Column Name: cat_brand_tri_repeat |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.l2_cat_tri_repeat Description:
#         Column Name: l2_cat_tri_repeat |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.cogs Description:
#         Column Name: cogs |
#         Sample values: None |
#         Data type: NUMERIC(33, 4) |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.reedmed_value Description:
#         Column Name: reedmed_value |
#         Sample values: None |
#         Data type: NUMERIC(31, 2) |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.enr_income Description:
#         Column Name: enr_income |
#         Sample values: None |
#         Data type: NUMERIC(31, 2) |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.enr_income_prop Description:
#         Column Name: enr_income_prop |
#         Sample values: None |
#         Data type: NUMERIC(31, 2) |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.cat_dept_tri_rip Description:
#         Column Name: cat_dept_tri_rip |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.cat_dept_brand_tri_rip Description:
#         Column Name: cat_dept_brand_tri_rip |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.ps_member_repeat_flag Description:
#         Column Name: ps_member_repeat_flag |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.emp_designation Description:
#         Column Name: emp_designation |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.staff_repeat_trialist_flag Description:
#         Column Name: staff_repeat_trialist_flag |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.staff_member_repeat_flag Description:
#         Column Name: staff_member_repeat_flag |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.storesales:
#  Column Sales.storesales.margin_amt Description:
#         Column Name: margin_amt |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: storesales |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.pk_id Description:
#         Column Name: pk_id |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.granularity Description:
#         Column Name: granularity |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.rowid Description:
#         Column Name: rowid |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.formatting Description:
#         Column Name: formatting |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.createddate Description:
#         Column Name: createddate |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.modifieddate Description:
#         Column Name: modifieddate |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.createdby Description:
#         Column Name: createdby |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.modifiedby Description:
#         Column Name: modifiedby |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.createdip Description:
#         Column Name: createdip |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.modifiedip Description:
#         Column Name: modifiedip |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: None
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.order_entry_id Description:
#         Column Name: order_entry_id |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Unique identifier for each order entry
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.order_date Description:
#         Column Name: order_date |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Date and time when the order was placed
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.order_id Description:
#         Column Name: order_id |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Unique identifier for each order
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.ordered_quantity Description:
#         Column Name: ordered_quantity |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: The quantity of the item ordered
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.total_price Description:
#         Column Name: total_price |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Total price for the ordered quantity
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.refund_per_unit Description:
#         Column Name: refund_per_unit |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Refund amount per unit
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.p_baseprice Description:
#         Column Name: p_baseprice |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Base price of the product
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.p_user Description:
#         Column Name: p_user |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: User identifier
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.p_mobile Description:
#         Column Name: p_mobile |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Mobile number of the user
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.order_status Description:
#         Column Name: order_status |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Status of the order (e.g., COMPLETED, PARTIALLY_CANCELLED, DELIVERY_IN_TRANSIT)
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.payment_status Description:
#         Column Name: payment_status |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
#         Table Owner: Sales |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Payment status of the order (e.g., PAID)
#
#
# Sales.ecommdenormdata:
#  Column Sales.ecommdenormdata.p_code Description:
#         Column Name: p_code |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: ecommdenormdata |
# ...
#
#
# Customer.FC_Customer_Master:
#  Column Customer.FC_Customer_Master.preferred_category_1_brand Description:
#         Column Name: preferred_category_1_brand |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: FC_Customer_Master |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Brand preferred in the first category
#
#
# Customer.FC_Customer_Master:
#  Column Customer.FC_Customer_Master.preferred_category_2_brand Description:
#         Column Name: preferred_category_2_brand |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: FC_Customer_Master |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Brand preferred in the second category
#
#
# Customer.FC_Customer_Master:
#  Column Customer.FC_Customer_Master.preferred_category_3_brand Description:
#         Column Name: preferred_category_3_brand |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: FC_Customer_Master |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Brand preferred in the third category
#
#
# Customer.FC_Customer_Master:
#  Column Customer.FC_Customer_Master.preferred_dept_1 Description:
#         Column Name: preferred_dept_1 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: FC_Customer_Master |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: First preferred department of the member
#
#
# Customer.FC_Customer_Master:
#  Column Customer.FC_Customer_Master.preferred_dept_2 Description:
#         Column Name: preferred_dept_2 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: FC_Customer_Master |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Second preferred department of the member
#
#
# Customer.FC_Customer_Master:
#  Column Customer.FC_Customer_Master.preferred_dept_3 Description:
#         Column Name: preferred_dept_3 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: FC_Customer_Master |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Third preferred department of the member
#
#
# Customer.Persona:
#  Column Customer.Persona.member_id Description:
#         Column Name: member_id |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Unique identifier for each member
#
#
# Customer.Persona:
#  Column Customer.Persona.gender Description:
#         Column Name: gender |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Gender of the customer (e.g., M for Male, F for Female)
#
#
# Customer.Persona:
#  Column Customer.Persona.fc_flag Description:
#         Column Name: fc_flag |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Flag indicating if the customer is a First Connect member (1 for Yes, 0 for No)
#
#
# Customer.Persona:
#  Column Customer.Persona.membership_tier Description:
#         Column Name: membership_tier |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Tier of membership the customer belongs to
#
#
# Customer.Persona:
#  Column Customer.Persona.membership_tier2 Description:
#         Column Name: membership_tier2 |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Tier of membership the customer belongs to (This is the one we need to refer)
#
#
# Customer.Persona:
#  Column Customer.Persona.membership_stage_id Description:
#         Column Name: membership_stage_id |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Stage and Tier mapping of membership
#
#
# Customer.Persona:
#  Column Customer.Persona.age_updated Description:
#         Column Name: age_updated |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Age of the customer
#
#
# Customer.Persona:
#  Column Customer.Persona.lifestage Description:
#         Column Name: lifestage |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description:  Lifestage category of the customer (e.g., SINGLE WOMAN, FAMILY WITH KIDS)
#
#
# Customer.Persona:
#  Column Customer.Persona.metro_city_customer Description:
#         Column Name: metro_city_customer |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Flag indicating if the customer resides in a metropolitan city (1 for Yes, 0 for No)
#
#
# Customer.Persona:
#  Column Customer.Persona.is_single_timer Description:
#         Column Name: is_single_timer |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Flag indicating if the customer is a single timer (1 for Yes, 0 for No)
#
#
# Customer.Persona:
#  Column Customer.Persona.purchase_gap_months Description:
#         Column Name: purchase_gap_months |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description:  Number of months since the last purchase
#
#
# Customer.Persona:
#  Column Customer.Persona.enrollment_in_months Description:
#         Column Name: enrollment_in_months |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Number of months since enrollment
#
#
# Customer.Persona:
#  Column Customer.Persona.recency_in_months Description:
#         Column Name: recency_in_months |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Number of months since the most recent activity
#
#
# Customer.Persona:
#  Column Customer.Persona.private_brands_shopper Description:
#         Column Name: private_brands_shopper |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Flag indicating if the customer shops private brands (1 for Yes, 0 for No)
#
#
# Customer.Persona:
#  Column Customer.Persona.premium_brand_shopper Description:
#         Column Name: premium_brand_shopper |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Flag indicating if the customer shops premium brands (1 for Yes, 0 for No)
#
#
# Customer.Persona:
#  Column Customer.Persona.overall_atv Description:
#         Column Name: overall_atv |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Overall average transaction value
#
#
# Customer.Persona:
#  Column Customer.Persona.overall_ipt Description:
#         Column Name: overall_ipt |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Overall average interval between purchases
#
#
# Customer.Persona:
#  Column Customer.Persona.overall_sales Description:
#         Column Name: overall_sales |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Overall total sales
#
#
# Customer.Persona:
#  Column Customer.Persona.store_sales Description:
#         Column Name: store_sales |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Total sales in physical stores
#
#
# Customer.Persona:
#  Column Customer.Persona.online_sales Description:
#         Column Name: online_sales |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Total sales online
#
#
# Customer.Persona:
#  Column Customer.Persona.eoss_shopper Description:
#         Column Name: eoss_shopper |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description:  Flag indicating if the customer is an end-of-season sale shopper (1 for Yes, 0 for No)
#
#
# Customer.Persona:
#  Column Customer.Persona.non_eoss_shopper Description:
#         Column Name: non_eoss_shopper |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Flag indicating if the customer is a non-end-of-season sale shopper (1 for Yes, 0 for No)
#
#
# Customer.Persona:
#  Column Customer.Persona.cluster Description:
#         Column Name: cluster |
#         Sample values: None |
#         Data type: INT64 |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Persona Customer segmentation cluster
#
#
# Customer.Persona:
#  Column Customer.Persona.cluster_name Description:
#         Column Name: cluster_name |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Name of the customer Persona segmentation cluster.
#
#
# Customer.Persona:
#  Column Customer.Persona.score_month Description:
#         Column Name: score_month |
#         Sample values: None |
#         Data type: DATETIME |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Month for which the Persona segements are calculated
#
#
# Customer.Persona:
#  Column Customer.Persona.recency_slab Description:
#         Column Name: recency_slab |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Slab/category based on recency
#
#
# Customer.Persona:
#  Column Customer.Persona.age_slab Description:
#         Column Name: age_slab |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Slab/category based on age
#
#
# Customer.Persona:
#  Column Customer.Persona.single_repeater Description:
#         Column Name: single_repeater |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Indicates if the customer is a single timer or a repeater
#
#
# Customer.Persona:
#  Column Customer.Persona.ethnicity Description:
#         Column Name: ethnicity |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Ethnicity of the customer
#
#
# Customer.Persona:
#  Column Customer.Persona.discount Description:
#         Column Name: discount |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Overall discount percentage
#
#
# Customer.Persona:
#  Column Customer.Persona.ps_contri Description:
#         Column Name: ps_contri |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Contribution from personal shopper sales
#
#
# Customer.Persona:
#  Column Customer.Persona.mall_store_sales Description:
#         Column Name: mall_store_sales |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Total sales in mall stores.
#
#
# Customer.Persona:
#  Column Customer.Persona.standalone_store_sales Description:
#         Column Name: standalone_store_sales |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Total sales in standalone stores
#
#
# Customer.Persona:
#  Column Customer.Persona.airport_store_sales Description:
#         Column Name: airport_store_sales |
#         Sample values: None |
#         Data type: BIGNUMERIC(48, 10) |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Total sales in airport stores
#
#
# Customer.Persona:
#  Column Customer.Persona.discount_slab Description:
#         Column Name: discount_slab |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Slab/category based on discount percentage
#
#
# Customer.Persona:
#  Column Customer.Persona.ps_contri_slab Description:
#         Column Name: ps_contri_slab |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Slab/category based on private sales contribution
#
#
# Customer.Persona:
#  Column Customer.Persona.storename Description:
#         Column Name: storename |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Name of the store where the customer made purchases
#
#
# Customer.Persona:
#  Column Customer.Persona.zone Description:
#         Column Name: zone |
#         Sample values: None |
#         Data type: STRING |
#         Table Name: Persona |
#         Table Owner: Customer |
#         Project_id: ss-jarvis-npd-svc-prj-01
#         Column description: Zone where the store is located

# %% [markdown]
# #BigQuery Vector Embedding

# %%
if ENABLE_ANALYTICS is True:
  # Create a BigQuery client
  bq_client = bigquery.Client(location=DATASET_LOCATION, project=PROJECT_ID)

  # Create a dataset
  try:
    dataset = bq_client.create_dataset(dataset=DATASET_NAME)
  except Exception as e:
    print('Failed to create the dataset\n')
    print(str(e))
# Out:
# Failed to create the dataset
#
# 409 POST https://bigquery.googleapis.com/bigquery/v2/projects/ss-genai-npd-svc-prj-01/datasets?prettyPrint=false: Already Exists: Dataset ss-genai-npd-svc-prj-01:nl2sql

# %%
# def text_embedding(question):
#     """Text embedding with a Large Language Model."""
#     model = TextEmbeddingModel.from_pretrained(embeddings_model)
#     embeddings = model.get_embeddings([question])
#     for embedding in embeddings:
#         vector = embedding.values
#         print(f"Length of Embedding Vector: {len(vector)}")
#     return vector

# %%
# Configure gcloud.
# !gcloud config set project {PROJECT_ID}

# Grant Cloud SQL Client role to authenticated user
current_user = !gcloud auth list --filter=status:ACTIVE --format="value(account)"

# !gcloud projects add-iam-policy-binding {PROJECT_ID} \
  --member=user:{current_user[0]} \
  --role="roles/cloudsql.client"

  # Enable Cloud SQL Admin API
# !gcloud services enable sqladmin.googleapis.com
# !gcloud services enable aiplatform.googleapis.com

# %%
def create_bq_metadata_table():
  # data_table.DataTable(table_comments_df)

  client = bigquery.Client()
  table_comments_df.to_gbq(destination_table=f'{DATAPROJECT_ID}.{DATASET_NAME}.table_comments',
            project_id=f'{DATAPROJECT_ID}',
            if_exists='replace')

  columns_df.to_gbq(destination_table=f'{DATAPROJECT_ID}.{DATASET_NAME}.column_comments',
            project_id=f'{DATAPROJECT_ID}',
            if_exists='replace')

  sql_ddl = f"""CREATE TABLE IF NOT EXISTS {DATAPROJECT_ID}.{DATASET_NAME}.sql(
                                  question string,
                                  generated_sql string);"""

  pandas_gbq.read_gbq(sql_ddl)
  return True;

# %%
def create_bq_embeddings():
  table_embeddings_ddl="""CREATE OR REPLACE TABLE `ss-genai-npd-svc-prj-01.nl2sql.table_comments_embeddings` AS
SELECT * FROM ML.GENERATE_EMBEDDING(
  MODEL `ss-genai-npd-svc-prj-01.nl2sql.embedding_model`,
  (
    select to_hex(md5(concat(project_id,'.',owner,'.',table_name,'.',detailed_description))) as idx, detailed_description, project_id, owner, table_name,current_datetime() as epoch_time,detailed_description as content  from ss-genai-npd-svc-prj-01.nl2sql.table_comments
    where length(detailed_description)>0
  )
);"""

  column_embeddings_ddl="""CREATE OR REPLACE TABLE `ss-genai-npd-svc-prj-01.nl2sql.column_comments_embeddings` AS
SELECT * FROM ML.GENERATE_EMBEDDING(
  MODEL `ss-genai-npd-svc-prj-01.nl2sql.embedding_model`,
  (
    select to_hex(md5(concat(project_id,'.',owner,'.',table_name,'.',detailed_description))) as idx, detailed_description, project_id, owner, table_name,column_name,current_datetime() as epoch_time,detailed_description as content  from
    ss-genai-npd-svc-prj-01.nl2sql.column_comments  where length(detailed_description)>0
  )
);"""
  sql_embeddings_ddl="""
CREATE OR REPLACE TABLE `ss-genai-npd-svc-prj-01.nl2sql.sql_embeddings` AS
SELECT * FROM ML.GENERATE_EMBEDDING(
  MODEL `ss-genai-npd-svc-prj-01.nl2sql.embedding_model`,
  (
    select to_hex(md5((question))) as idx, question,generated_sql,current_datetime() as epoch_time,question as content  from ss-genai-npd-svc-prj-01.nl2sql.sql where length(question)>0
    )
);"""

  client=bigquery.Client()

  pandas_gbq.read_gbq(table_embeddings_ddl)
  pandas_gbq.read_gbq(column_embeddings_ddl)
  pandas_gbq.read_gbq(sql_embeddings_ddl)
  return True;

# %%
if create_bq_metadata_table():
  if create_bq_embeddings():
    print("Embeddings for tables, columns and sql are successfully generated")
  else:
    print("Failed to generate embeddings for tables, columns and sql")
else:
  print("Failed to create metadata tables for embeedings")
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 7182.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 7958.83it/s]
# Downloading: |          |
# Downloading:   0%|          |
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/_pandas_helpers.py:267: UserWarning: Unable to determine type for field 'ml_generate_embedding_statistics'.
#   warnings.warn("Unable to determine type for field '{}'.".format(bq_field.name))
# Downloading: 100%|██████████|
# Downloading:   0%|          |
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/_pandas_helpers.py:267: UserWarning: Unable to determine type for field 'ml_generate_embedding_statistics'.
#   warnings.warn("Unable to determine type for field '{}'.".format(bq_field.name))
# Downloading: 100%|██████████|
# Downloading: |          |
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/_pandas_helpers.py:267: UserWarning: Unable to determine type for field 'ml_generate_embedding_statistics'.
#   warnings.warn("Unable to determine type for field '{}'.".format(bq_field.name))
# Downloading: |          |
# Embeddings for tables, columns and sql are successfully generated
