# %% [markdown]
# ![Screenshot 2023-10-27 at 1.30.33 AM.png](data:image/png;base64,...)

# %% [markdown]
# * Author: [leip@](https://moma.corp.google.com/person/leip)
# * Date: 10/27/23

# %% [markdown]
# ## Overview
#
# Codey models are text-to-code models from Google AI, trained on a massive code related dataset. You can generate code related responses for different scenarios such as writing functions, unit tests, debugging, autocompleting and etc. This notebook is to show you how to use Codey APIs to do tasks below.
#
# User Journey 1.2: Generate code for custom libraries based on org private repo, new languages, and new code patterns
#
# - Generate functions
# - Explain code
# - Generate unit tests
# - Generate comment
# - Assisted code refactoring/modification

# %% [markdown]
# ## Pre Work

# %%
# @title Install Libraries
import sys
if 'google.colab' in sys.modules:
    ! pip install google-cloud-aiplatform
    ! pip install google-cloud-discoveryengine
    ! pip install jsonlines
    from google.colab import auth as google_auth
    google_auth.authenticate_user()

# %%
import sys
import json
import os
import vertexai
from typing import Dict, List, Optional, Tuple
from google.cloud import discoveryengine
from google.protobuf.json_format import MessageToDict

# %%
# @title Initialize Vertex AI
import vertexai
from vertexai.preview.language_models import CodeGenerationModel

VERTEX_API_PROJECT = '<your project>'
VERTEX_API_LOCATION = '<location>'

vertexai.init(project=VERTEX_API_PROJECT, location=VERTEX_API_LOCATION)
code_generation_model = CodeGenerationModel.from_pretrained("code-bison@001")

def send_prompt(prefix, max_token=1024, model = code_generation_model):
    parameters = {
    "temperature": 0.2,
    "max_output_tokens": max_token
    }

    response = model.predict(
    prefix=prefix, **parameters
    )

    return response.text

# %%
# @title Set Up Vertex AI Search API Parameters
project_id = "<project id>"
location = "<location>"
search_engine_id = "<search engine id of the vertex AI search API>"
serving_config_id = "<search config id of the vertex AI search API> - usually it's default"

# %% [markdown]
# ## Fine-Tune Codey Model to Learna New API

# %%
# @title Step 1: Generate Vertex AI Search API Code using Untuned Codey Model
prompt = """
Generate a function to send search queries to the Vertex AI Search API and retrieve the search results.
"""
print(send_prompt (prompt))
# Out:
# ```python
# def search_vertex_ai(query):
#
#   # Create a client for the Vertex AI Search API.
#   client = VertexAiSearchClient()
#
#   # Create a search request.
#   request = SearchRequest()
#   request.query = query
#
#   # Send the search request.
#   response = client.search(request)
#
#   # Get the search results.
#   results = response.results
#
#   # Return the search results.
#   return results
# ```

# %%
# @title Step 2: Tune Model to Understand the Latest Vertex AI Search API
model = CodeGenerationModel.from_pretrained("code-bison@001")

training_dataset_url = "<dataset URL - gcs bucket>"
model.tune_model(
    training_data=training_dataset_url,
    train_steps=200,
    tuning_job_location="<job location>",
    tuned_model_location="<model location>",
    model_display_name="<display name>"
    )

# %%
# @title Step 3: Query Tuned Model to Generate Vertext AI Search Code
list_models = CodeGenerationModel.from_pretrained("code-bison@001").list_tuned_model_names()
TUNED_MODEL_NAME = list_models[0]
tuned_model = CodeGenerationModel.get_tuned_model(TUNED_MODEL_NAME)
vertexai_search_code = send_prompt(prefix=prompt,model= tuned_model)
vertexai_search_code = vertexai_search_code.removeprefix(' ```python').removesuffix('```')
print(vertexai_search_code)
# Out:
# ```python
# def search_sample(
#     project_id: str,
#     location: str,
#     search_engine_id: str,
#     serving_config_id: str,
#     search_query: str,
# ) -> List[discoveryengine.SearchResponse.SearchResult]:
#     client = discoveryengine.SearchServiceClient()
#     serving_config = client.serving_config_path(
#         project=project_id,
#         location=location,
#         data_store=search_engine_id,
#         serving_config=serving_config_id,
#     )
#
#     request = discoveryengine.SearchRequest(
#         serving_config=serving_config,
#         query=search_query,
#     )
#     response = client.search(request)
#
#     return response

# %%
# @title Step 4: Use the Generated Code to Query Vertex Search Engine
def search_sample(
    project_id: str,
    location: str,
    search_engine_id: str,
    serving_config_id: str,
    search_query: str,
) -> List[discoveryengine.SearchResponse.SearchResult]:
    client = discoveryengine.SearchServiceClient()
    serving_config = client.serving_config_path(
        project=project_id,
        location=location,
        data_store=search_engine_id,
        serving_config=serving_config_id,
    )

    request = discoveryengine.SearchRequest(
        serving_config=serving_config,
        query=search_query,
    )
    response = client.search(request)

    return response

# %%
search_query = "how to improve campaign performance"
results = search_sample(project_id,location,search_engine_id,serving_config_id,search_query)
print(results)
# Out:
# SearchPager<results {
#   id: "0"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/0"
#     id: "0"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10724817?hl=en"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10724817?hl=en"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "About <b>Performance</b> Max <b>campaigns</b> - Google Ads Help"
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10724817?hl=en"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "cse_image"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "src"
#                         value {
#                           string_value: "https://storage.googleapis.com/support-kms-prod/IE5LEbfyvxDASQbKgGn9vsayo0cTQkkp2Lne"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#             fields {
#               key: "cse_thumbnail"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "height"
#                         value {
#                           string_value: "246"
#                         }
#                       }
#                       fields {
#                         key: "src"
#                         value {
#                           string_value: "https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQm0i5Em5JiaVYnc4Xv783xOdNAhx1fmgWGP7MFvu5OR4g0ZKIr6JMEj0Fg"
#                         }
#                       }
#                       fields {
#                         key: "width"
#                         value {
#                           string_value: "205"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "... <b>improve</b> your <b>campaign performance</b>. You can also provide important inputs about what types of conversions are most valuable to your business by applying&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "... improve your campaign performance. You can also provide important inputs about what types of conversions are most valuable to your business by applying\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "About Performance Max campaigns - Google Ads Help"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "1"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/1"
#     id: "1"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/7653465?hl=en"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/7653465?hl=en"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "<b>Improve</b> your Smart <b>campaign&#39;s performance</b> - Google Ads Help"
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/7653465?hl=en"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "<b>Improve</b> your Smart <b>campaign&#39;s performance</b> &middot; Choose the right keyword themes for your Smart <b>campaigns</b> &middot; Check your location settings &middot; Review your budget &middot; Write&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "Improve your Smart campaign\'s performance \302\267 Choose the right keyword themes for your Smart campaigns \302\267 Check your location settings \302\267 Review your budget \302\267 Write\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "Improve your Smart campaign\'s performance - Google Ads Help"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "2"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/2"
#     id: "2"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/13451710?hl=en-GB"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/13451710?hl=en-GB"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "<b>Upgrade</b> your display <b>campaigns</b> to <b>Performance</b> Max <b>campaigns</b> ..."
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/13451710?hl=en-GB"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "<b>Upgrade</b> from your <b>campaigns</b> page &middot; In your <b>campaigns</b> page, you might find a notification recommending you to <b>upgrade</b> to <b>Performance</b> Max on the right side of the&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "Upgrade from your campaigns page \302\267 In your campaigns page, you might find a notification recommending you to upgrade to Performance Max on the right side of the\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "Upgrade your display campaigns to Performance Max campaigns ..."
#         }
#       }
#     }
#   }
# }
# results {
#   id: "3"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/3"
#     id: "3"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10995103?hl=en"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10995103?hl=en"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "About conversion goals - Google Ads Help"
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10995103?hl=en"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "The updates are designed to <b>improve</b> the <b>performance</b> of your <b>campaigns</b> by keeping a strong focus on your advertising objectives. Your <b>campaign</b> bidding&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "The updates are designed to improve the performance of your campaigns by keeping a strong focus on your advertising objectives. Your campaign bidding\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "About conversion goals - Google Ads Help"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "4"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/4"
#     id: "4"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/11385582?hl=en"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/11385582?hl=en"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "Optimization tips for <b>Performance</b> Max <b>campaign</b> for all business ..."
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/11385582?hl=en"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "Use relevant audience lists as signals to speed up machine learning ramp-up and <b>enhance</b> your <b>campaign&#39;s</b> results. Use remarketing lists, custom intent, Customer&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "Use relevant audience lists as signals to speed up machine learning ramp-up and enhance your campaign\'s results. Use remarketing lists, custom intent, Customer\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "Optimization tips for Performance Max campaign for all business ..."
#         }
#       }
#     }
#   }
# }
# results {
#   id: "5"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/5"
#     id: "5"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/13780156?hl=en"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/13780156?hl=en"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "<b>Boost</b> your Search and Display results in <b>Performance</b> Max <b>campaigns</b>"
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/13780156?hl=en"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "Jul 25, 2023 <b>...</b> By upgrading to <b>Performance</b> Max, you&#39;ll be able to use new features like inventory-aware ad serving. It makes sure your out-of-stock pages don&#39;t&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "Jul 25, 2023 ... By upgrading to Performance Max, you\'ll be able to use new features like inventory-aware ad serving. It makes sure your out-of-stock pages don\'t\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "Boost your Search and Display results in Performance Max campaigns"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "6"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/6"
#     id: "6"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10384955?hl=en"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10384955?hl=en"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "Best practices guide: Drive better <b>performance</b> and measurement for ..."
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10384955?hl=en"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "cse_image"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "src"
#                         value {
#                           string_value: "https://storage.googleapis.com/support-kms-prod/2jWG6QCLmWllZUzWj7AvB2RpVc5D4lPDuXhy"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#             fields {
#               key: "cse_thumbnail"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "height"
#                         value {
#                           string_value: "159"
#                         }
#                       }
#                       fields {
#                         key: "src"
#                         value {
#                           string_value: "https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcShPgGXnsGfSK0hiHqCyHFh7zb0Bh8s0OIOI2PVrW2Rjv1uWeN29xSpGE0"
#                         }
#                       }
#                       fields {
#                         key: "width"
#                         value {
#                           string_value: "317"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "Jul 31, 2023 <b>...</b> Users who accept the prompt will <b>increase</b> your observed conversions, <b>improving</b> conversion modeling and <b>campaign</b> optimization. Learn more&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "Jul 31, 2023 ... Users who accept the prompt will increase your observed conversions, improving conversion modeling and campaign optimization. Learn more\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "Best practices guide: Drive better performance and measurement for ..."
#         }
#       }
#     }
#   }
# }
# results {
#   id: "7"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/7"
#     id: "7"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/12368488?hl=en"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/12368488?hl=en"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "Reminder: <b>Upgrade</b> your Smart Shopping <b>campaigns</b> to ..."
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/12368488?hl=en"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "Jul 21, 2022 <b>...</b> July 21, 2022Earlier this year, we previewed the timeline and process for upgrading your Smart Shopping and Local <b>campaigns</b> to <b>Performance</b>&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "Jul 21, 2022 ... July 21, 2022Earlier this year, we previewed the timeline and process for upgrading your Smart Shopping and Local campaigns to Performance\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "Reminder: Upgrade your Smart Shopping campaigns to ..."
#         }
#       }
#     }
#   }
# }
# results {
#   id: "8"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/8"
#     id: "8"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10725056?hl=en"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10725056?hl=en"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "About asset reporting in <b>Performance</b> Max - Google Ads Help"
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/10725056?hl=en"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "The asset report lists each asset used in a <b>Performance</b> Max <b>campaign</b> and allows you to compare <b>performance</b> across a variety of assets. ... To <b>improve</b> your&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "The asset report lists each asset used in a Performance Max campaign and allows you to compare performance across a variety of assets. ... To improve your\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "About asset reporting in Performance Max - Google Ads Help"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "9"
#   document {
#     name: "projects/1062767160769/locations/global/collections/default_collection/dataStores/ad-help_1688047621201/branches/0/documents/9"
#     id: "9"
#     derived_struct_data {
#       fields {
#         key: "displayLink"
#         value {
#           string_value: "support.google.com"
#         }
#       }
#       fields {
#         key: "formattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/11189316?hl=en"
#         }
#       }
#       fields {
#         key: "htmlFormattedUrl"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/11189316?hl=en"
#         }
#       }
#       fields {
#         key: "htmlTitle"
#         value {
#           string_value: "Multiply conversions across Google&#39;s ad channels with <b>Performance</b> ..."
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "https://support.google.com/google-ads/answer/11189316?hl=en"
#         }
#       }
#       fields {
#         key: "pagemap"
#         value {
#           struct_value {
#             fields {
#               key: "metatags"
#               value {
#                 list_value {
#                   values {
#                     struct_value {
#                       fields {
#                         key: "format-detection"
#                         value {
#                           string_value: "email=no"
#                         }
#                       }
#                       fields {
#                         key: "viewport"
#                         value {
#                           string_value: "width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=3,user-scalable=yes"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "htmlSnippet"
#                   value {
#                     string_value: "Advertisers who use Final URL expansion with <b>Performance</b> Max <b>campaigns</b> see an average <b>increase</b> of over 9% in conversions/conversion value at a similar Cost Per&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "Advertisers who use Final URL expansion with Performance Max campaigns see an average increase of over 9% in conversions/conversion value at a similar Cost Per\302\240..."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "Multiply conversions across Google\'s ad channels with Performance ..."
#         }
#       }
#     }
#   }
# }
# total_size: 13600
# attribution_token: "W_BaCgwIufSAqgYQ7fC6qAESJDY1M2FlYTgwLTAwMDAtMjZkMC04YjJhLTg4M2QyNGY4Yzg4YyIHR0VORVJJQyocwvCeFdSynRWOvp0VooaOIpyGjiKmi-8XxcvzFw"
# next_page_token: "MGO4MGOmRjMkNDO40SYyIGOtADZ2ITLwADMw0iZ3EWZhNTN2QiGCUvitqNEGoKkdnLCMIBMxIgC"
# guided_search_result {
# }
# summary {
# }
# >

# %%
# @title Step 5: Modify Generated Code with Protobuf Parsing Code
proto_prompt = """
Create a function to send search requests to Vertex AI Search API, convert the protobuf search response to a dictionary, and return the dictionary result.
"""
vertexai_search_code = send_prompt(prefix=proto_prompt,model= tuned_model)
vertexai_search_code = vertexai_search_code.removeprefix(' ```python').removesuffix('```')
print(vertexai_search_code)
# Out:
# ```python
# def search_sample(
#     project_id: str,
#     location: str,
#     search_engine_id: str,
#     serving_config_id: str,
#     search_query: str,
# ) -> List[discoveryengine.SearchResponse.SearchResult]:
#     client = discoveryengine.SearchServiceClient()
#     serving_config = client.serving_config_path(
#         project=project_id,
#         location=location,
#         data_store=search_engine_id,
#         serving_config=serving_config_id,
#     )
#
#     request = discoveryengine.SearchRequest(
#         serving_config=serving_config,
#         query=search_query,
#     )
#     response = client.search(request)
#     results = [MessageToDict(result.document._pb) for result in response.results]
#
#     return results

# %%
# @title Step 6: Use the Generated Code to Query Vertex Search Engine
def search_sample(
    project_id: str,
    location: str,
    search_engine_id: str,
    serving_config_id: str,
    search_query: str,
) -> List[discoveryengine.SearchResponse.SearchResult]:
    client = discoveryengine.SearchServiceClient()
    serving_config = client.serving_config_path(
        project=project_id,
        location=location,
        data_store=search_engine_id,
        serving_config=serving_config_id,
    )

    request = discoveryengine.SearchRequest(
        serving_config=serving_config,
        query=search_query,
    )
    response = client.search(request)
    results = [MessageToDict(result.document._pb) for result in response.results]

    return results


search_query = "how to improve campaign performance"
results = search_sample(project_id,location,search_engine_id,serving_config_id,search_query)

for result in results:
  print(result['derivedStructData']['title'])
  print(result['derivedStructData']['link'])
# Out:
# About Performance Max campaigns - Google Ads Help
# https://support.google.com/google-ads/answer/10724817?hl=en
# Improve your Smart campaign's performance - Google Ads Help
# https://support.google.com/google-ads/answer/7653465?hl=en
# Upgrade your display campaigns to Performance Max campaigns ...
# https://support.google.com/google-ads/answer/13451710?hl=en-GB
# About conversion goals - Google Ads Help
# https://support.google.com/google-ads/answer/10995103?hl=en
# Optimization tips for Performance Max campaign for all business ...
# https://support.google.com/google-ads/answer/11385582?hl=en
# Boost your Search and Display results in Performance Max campaigns
# https://support.google.com/google-ads/answer/13780156?hl=en
# Reminder: Upgrade your Smart Shopping campaigns to ...
# https://support.google.com/google-ads/answer/12368488?hl=en
# About asset reporting in Performance Max - Google Ads Help
# https://support.google.com/google-ads/answer/10725056?hl=en
# 5 ways to use Quality Score to improve your performance - Google ...
# https://support.google.com/google-ads/answer/6167130?hl=en
# Multiply conversions across Google's ad channels with Performance ...
# https://support.google.com/google-ads/answer/11189316?hl=en

# %%
# @title Step 7: Generate Unit Test
unit_test_prompt = f"""
Generate unit test to cover this block of code {vertexai_search_code}
"""
print(send_prompt (prefix=unit_test_prompt))
# Out:
# ```python
# import unittest
#
# from google.cloud import discoveryengine
# from google.protobuf import json_format
#
#
# class TestSearchSample(unittest.TestCase):
#
#     def test_search_sample(self):
#         project_id = "my-project"
#         location = "us-central1"
#         search_engine_id = "my-search-engine"
#         serving_config_id = "my-serving-config"
#         search_query = "hello world"
#
#         results = search_sample(
#             project_id=project_id,
#             location=location,
#             search_engine_id=search_engine_id,
#             serving_config_id=serving_config_id,
#             search_query=search_query,
#         )
#
#         self.assertIsNotNone(results)
#         self.assertIsInstance(results, list)
#         self.assertGreater(len(results), 0)
#
#         for result in results:
#             self.assertIsNotNone(result)
#             self.assertIsInstance(result, discoveryengine.SearchResponse.SearchResult)
#             self.assertIsNotNone(result.document)
#             self.assertIsInstance(result.document, discoveryengine.Document)
#
# ```

# %%
# @title Step 8: Explain the Code
explain_prompt = f"""
Explain this block of code {vertexai_search_code} line by line
"""
print(send_prompt (prefix=explain_prompt))
# Out:
# The function `search_sample` takes five arguments:
#
#   * `project_id`: The ID of the project that the search engine belongs to.
#   * `location`: The location of the search engine.
#   * `search_engine_id`: The ID of the search engine.
#   * `serving_config_id`: The ID of the serving configuration to use.
#   * `search_query`: The search query to use.
#
# The function first creates a client for the Discovery Engine API. It then uses
# the client to create a `serving_config` object, which specifies the project,
# location, search engine ID, and serving configuration ID.
#
# The function then creates a `SearchRequest` object, which specifies the
# `serving_config` and the search query. It then sends the request to the
# Discovery Engine API and gets a `SearchResponse` object in return.
#
# The function then iterates over the `results` field of the `SearchResponse`
# object and converts each result to a dictionary. It then returns the list of
# dictionaries.
#
# Here is a more detailed explanation of each line of code:
#
# * `def search_sample(
#     project_id: str,
#     location: str,
#     search_engine_id: str,
#     serving_config_id: str,
#     search_query: str,
# ) -> List[discoveryengine.SearchResponse.SearchResult]:`: This is the function definition. It takes five arguments and returns a list of dictionaries.
# * `client = discoveryengine.SearchServiceClient()`: This creates a client for the Discovery Engine API.
# * `serving_config = client.serving_config_path(
#         project=project_id,
#         location=location,
#         data_store=search_engine_id,
#         serving_config=serving_config_id,
#     )`: This creates a `serving_config` object, which specifies the project, location, search engine ID, and serving configuration ID.
# * `request = discoveryengine.SearchRequest(
#         serving_config=serving_config,
#         query=search_query,
#     )`: This creates a `SearchRequest` object, which specifies the `serving_config` and the search query.
# * `response = client.search(request)`: This sends the `SearchRequest` object to the Discovery Engine API and gets a `SearchResponse` object in return.
# * `results = [MessageToDict(result.document._pb) for result in response.results]`: This iterates over the `results` field of the `SearchResponse` object and converts each result to a dictionary.
# * `return results`: This returns the list of dictionaries.

# %%
# @title Step 9: Refactor the Code
refactor_prompt = f"""
Refactor this block of code {vertexai_search_code} by using descriptive and meaningful names and comments
"""
print(send_prompt(prefix=refactor_prompt))
# Out:
# ```python
# def search_sample(
#     project_id: str,
#     location: str,
#     search_engine_id: str,
#     serving_config_id: str,
#     search_query: str,
# ) -> List[discoveryengine.SearchResponse.SearchResult]:
#     """
#     Searches for results in the given search engine.
#
#     Args:
#         project_id: The ID of the project that owns the search engine.
#         location: The location of the search engine.
#         search_engine_id: The ID of the search engine.
#         serving_config_id: The ID of the serving config to use.
#         search_query: The query to search for.
#
#     Returns:
#         A list of search results.
#     """
#
#     client = discoveryengine.SearchServiceClient()
#     serving_config = client.serving_config_path(
#         project=project_id,
#         location=location,
#         data_store=search_engine_id,
#         serving_config=serving_config_id,
#     )
#
#     request = discoveryengine.SearchRequest(
#         serving_config=serving_config,
#         query=search_query,
#     )
#     response = client.search(request)
#
#     return response
# ```

# %%
# @title Step 10: Generate Comments
comment_prompt = f"""
Generate line-by-line comments for this block of code {vertexai_search_code}
"""
print(send_prompt (prefix=comment_prompt))
# Out:
# This function performs a search using the Discovery Engine API.
#
# The function takes four arguments:
#
# * `project_id`: The ID of the project that the search engine belongs to.
# * `location`: The location of the search engine.
# * `search_engine_id`: The ID of the search engine.
# * `serving_config_id`: The ID of the serving configuration to use for the search.
#
# The function returns a list of `SearchResult` objects, which contain information about the documents that were found in the search.
#
# Here is a more detailed explanation of each line of code:
#
# * `client = discoveryengine.SearchServiceClient()`: This creates a client object for the Discovery Engine API.
# * `serving_config = client.serving_config_path(project=project_id, location=location, data_store=search_engine_id, serving_config=serving_config_id)`: This constructs the path to the serving configuration to use for the search.
# * `request = discoveryengine.SearchRequest(serving_config=serving_config, query=search_query)`: This creates a `SearchRequest` object, which specifies the serving configuration to use and the search query.
# * `response = client.search(request)`: This sends the `SearchRequest` to the Discovery Engine API and returns the response.
# * `results = [MessageToDict(result.document._pb) for result in response.results]`: This converts the `SearchResult` objects in the response to a list of dictionaries.
# * `return results`: This returns the list of dictionaries.
